# %% [markdown]
# # Pandas -- Data Science

# %% [markdown]
# <tr>
# <td> <img src = "https://miro.medium.com/max/1400/0*DdYAfo_NsnAeHrur" width="80%" height="80%"/ </td>
# <td> <img src = "https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/2880px-Pandas_logo.svg.png" width="50%" height="50%"/> </td>
# </tr>

# %% [markdown]
# **Pandas** is a popular software library for the Python in data manipulation and analysis. It is one of the most important and useful tools in the arsenal of a Data Scientist and a Data Analyst.

# %% [markdown]
# **Four steps for business intelligence:**
# 1. data collection
# 2. data analysis
# 3. data visualization
# 4. decision-making

# %% [markdown]
# # Introduction

# %% [markdown]
# Install Pandas

# %%
#import libraries
import pandas as pd

# %%
#create an example dataset
mydata = { #dataset name
  'cars': ["BMW", "Volvo", "Ford"], #'column name':[data]
  'passings': [3, 7, 2]
} #end dictionary

mydata

# %%
#convert the data into pandas dataframe
mydf = pd.DataFrame(mydata)
mydf

# %%
#display the first row
print(mydf[:1])

# %%
#refer to the row index 0:
print(mydf.loc[0])

# %%
#use a list of indexes:
print(mydf.loc[[0, 1]])

# %%
#instead of using the default index [0....n], name your own index
mydf2 = pd.DataFrame(mydata, index = ["Car1", "Car2", "Car3"])

print(mydf2)

# %%
#refer to the named index:
print(mydf2.loc["Car2"])

# %%
# rename columns
mydf2 = mydf2.rename(columns={'cars': 'Car_brands'})
mydf2.head()

# %% [markdown]
# ### JSON data format -- Twitter data

# %% [markdown]
# Example:https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/overview

# %% [markdown]
# {
#   "created_at": "Thu Apr 06 15:24:15 +0000 2017",
#   "id_str": "850006245121695744",
#   "text": "1\/ Today we\u2019re sharing our vision for the future of the Twitter API platform!\nhttps:\/\/t.co\/XweGngmxlP",
#   "user": {
#     "id": 2244994945,
#     "name": "Twitter Dev",
#     "screen_name": "TwitterDev",
#     "location": "Internet",
#     "url": "https:\/\/dev.twitter.com\/",
#     "description": "Your official source for Twitter Platform news, updates & events. Need technical help? Visit https:\/\/twittercommunity.com\/ \u2328\ufe0f #TapIntoTwitter"
#   },
#   "place": {
#   },
#   "entities": {
#     "hashtags": [
#     ],
#     "urls": [
#       {
#         "url": "https:\/\/t.co\/XweGngmxlP",
#         "unwound": {
#           "url": "https:\/\/cards.twitter.com\/cards\/18ce53wgo4h\/3xo1c",
#           "title": "Building the Future of the Twitter API Platform"
#         }
#       }
#     ],
#     "user_mentions": [
#     ]
#   }
# }

# %%
# JSON to Pandas dataframe
json = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

dfjson = pd.DataFrame(json)

dfjson

# %%
#query sepecific columns
print(dfjson[["Duration","Maxpulse"]])

# %% [markdown]
# ### Parsing JSON Dataset

# %% [markdown]
# **“Normalize” semi-structured JSON data into a flat table**

# %%
from pandas.io.json import json_normalize

# %%
jsondata2 = [{'state': 'Florida',
      'shortname': 'FL',
       'info': {
            'governor': 'Rick Scott'
         },
#parent node         
              'counties': [{'name': 'Dade', 'population': 12345},
                    {'name': 'Broward', 'population': 40000},
                     {'name': 'Palm Beach', 'population': 60000}]}, 
        {'state': 'Ohio',
        'shortname': 'OH',
          'info': {
              'governor': 'John Kasich'
        },
      'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
norm = json_normalize(jsondata2, 'counties', ['state', 'shortname',
                                           ['info', 'governor']])
norm

# %% [markdown]
# # Data cleaning

# %%
#load nba dataset
nba = pd.read_csv("https://cdncontribute.geeksforgeeks.org/wp-content/uploads/nba.csv")

nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457                NaN        NaN
#
# [458 rows x 9 columns]

# %%
import numpy as np
# add one coulmn with random numbers
nba['Add'] = np.random.randint(0,5, size=len(nba))
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  Add
# 0                Texas  7730337.0    4
# 1            Marquette  6796117.0    1
# 2    Boston University        NaN    1
# 3        Georgia State  1148640.0    3
# 4                  NaN  5000000.0    2
# ..                 ...        ...  ...
# 453             Butler  2433333.0    4
# 454                NaN   900000.0    3
# 455                NaN  2900000.0    0
# 456             Kansas   947276.0    0
# 457                NaN        NaN    1
#
# [458 rows x 10 columns]

# %%
#save the data to csv file
nba.to_csv("nba1.csv")

# %%
#remove the index
nba.to_csv("nba2.csv",index=False)

# %%
#save the data to excel file
from openpyxl.workbook import Workbook
nba.to_excel("nba.xlsx",
             sheet_name='nba_example', index=False)

# %%
#read excel file
readxlsx = pd.read_excel('nba.xlsx',sheet_name='nba_example')
readxlsx

#if you have the following error message, you need to install openpyxl
#ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.
#!pip install openpyxl
#https://anaconda.org/anaconda/openpyxl
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  Add
# 0                Texas  7730337.0    4
# 1            Marquette  6796117.0    1
# 2    Boston University        NaN    1
# 3        Georgia State  1148640.0    3
# 4                  NaN  5000000.0    2
# ..                 ...        ...  ...
# 453             Butler  2433333.0    4
# 454                NaN   900000.0    3
# 455                NaN  2900000.0    0
# 456             Kansas   947276.0    0
# 457                NaN        NaN    1
#
# [458 rows x 10 columns]

# %%
# in real world, when you facing a very large dataset, you don't have to show them all
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Add
# 0              Texas  7730337.0    4
# 1          Marquette  6796117.0    1
# 2  Boston University        NaN    1
# 3      Georgia State  1148640.0    3
# 4                NaN  5000000.0    2

# %%
# display the entire dataset
pd.set_option('display.max_rows',458)

# %%
#nba

# %%
# describe your dataset
nba.describe()
# Out:
#            Number         Age      Weight        Salary         Add
# count  457.000000  457.000000  457.000000  4.460000e+02  458.000000
# mean    17.678337   26.938731  221.522976  4.842684e+06    1.936681
# std     15.966090    4.404016   26.368343  5.229238e+06    1.388578
# min      0.000000   19.000000  161.000000  3.088800e+04    0.000000
# 25%      5.000000   24.000000  200.000000  1.044792e+06    1.000000
# 50%     13.000000   26.000000  220.000000  2.839073e+06    2.000000
# 75%     25.000000   30.000000  240.000000  6.500000e+06    3.000000
# max     99.000000   40.000000  307.000000  2.500000e+07    4.000000

# %%
nba.info()
#if you see the following error:
#TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
#you need to update your Pandas and Numpy, you need to have pandas>=1.0.5
#anaconda prompt: conda update pandas/numpy
#check the version of your pandas: conda list pandas/numpy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
#  9   Add       458 non-null    int64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 35.9+ KB

# %% [markdown]
# ## Empty cells / Null values

# %%
#remove rows that contains null values (NaN)
new_nba = nba.dropna()
#new_nba

# %% [markdown]
# **Note**: By default, the dropna() method returns a new DataFrame, and will not change the original.

# %%
new_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    object
#  2   Number    364 non-null    float64
#  3   Position  364 non-null    object
#  4   Age       364 non-null    float64
#  5   Height    364 non-null    object
#  6   Weight    364 non-null    float64
#  7   College   364 non-null    object
#  8   Salary    364 non-null    float64
#  9   Add       364 non-null    int64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 31.3+ KB

# %%
# check how many rows and columns for a dataframe
nba.shape
# Out:
# (458, 10)

# %% [markdown]
# If you want to change the original DataFrame, use the inplace = True argument:

# %%
# change in the originial dataframe
#nba.dropna(inplace = True)#drop all the rows contain null values
#nba

# %%
#Replace all empty/null Values with a specific value
#nba.fillna(130000, inplace = True) #hint: get back the original dataframe if you run the previous module
#nba

# %%
#use replace() to replace the null values with 0 for a specific column
#import numpy as np
nba["Salary"].replace(np.nan, 0)

# %%
# check unique values for a column 
nba.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz',
#        nan], dtype=object)

# %%
# Action 1: Count how many teams use len()
print(len(nba.Team.unique()))
# Out:
# 31

# %%
# Action 2: how many colleges these football palyers from?
# hints: check the unique values for "College", then count the numbers use len()
print(len(nba.College.unique()))
# Out:
# 119

# %%
# replace strings with numbers e.g., replace the team "Boston Celtics" to 1 and "Brooklyn Nets" to 2
# change categorical data to numeric
teams = {'Boston Celtics': 1, 'Brooklyn Nets': 2}

nba_replace = nba.replace({'Team': teams})
nba_replace

# %%
# Action 3: replace all the team names with numbers 
# Change categorical data to numeric
new_dict = {}
count = 0
for team in nba.Team.unique():
    new_dict[team] = count
    count += 1
nba_replace = nba.replace({'Team': new_dict})
nba_replace
# Out:
#                          Name  Team  Number Position   Age Height  Weight  \
# 0               Avery Bradley     0     0.0       PG  25.0    6-2   180.0
# 1                 Jae Crowder     0    99.0       SF  25.0    6-6   235.0
# 2                John Holland     0    30.0       SG  27.0    6-5   205.0
# 275             Alexis Ajinca    18    42.0        C  28.0    7-2   248.0
# 276             Ryan Anderson    18    33.0       PF  28.0   6-10   240.0
# 277                 Omer Asik    18     3.0        C  29.0    7-0   255.0
# 278              Luke Babbitt    18     8.0       SF  26.0    6-9   225.0
# 279               Norris Cole    18    30.0       PG  27.0    6-2   175.0
# 280          Dante Cunningham    18    44.0       PF  29.0    6-8   230.0
# 281             Anthony Davis    18    23.0       PF  23.0   6-10   253.0
# 282        Bryce Dejean-Jones    18    31.0       SG  23.0    6-6   203.0
# 283             Toney Douglas    18    16.0       PG  30.0    6-2   195.0
# 284               James Ennis    18     4.0       SF  25.0    6-7   210.0
# 285              Tyreke Evans    18     1.0       SG  26.0    6-6   220.0
# 286               Tim Frazier    18     2.0       PG  25.0    6-1   170.0
# 287                Alonzo Gee    18    15.0       SF  29.0    6-6   225.0
# 288               Eric Gordon    18    10.0       SG  27.0    6-4   215.0
# 289           Jordan Hamilton    18    25.0       SG  25.0    6-7   220.0
# 290              Jrue Holiday    18    11.0       PG  25.0    6-4   205.0
# 291           Orlando Johnson    18     0.0       SG  27.0    6-5   220.0
# 292          Kendrick Perkins    18     5.0        C  31.0   6-10   270.0
# 293          Quincy Pondexter    18    20.0       SF  28.0    6-7   220.0
# 294         LaMarcus Aldridge    19    12.0       PF  30.0   6-11   240.0
# 295             Kyle Anderson    19     1.0       SF  22.0    6-9   230.0
# 296               Matt Bonner    19    15.0        C  36.0   6-10   235.0
# 297                Boris Diaw    19    33.0        C  34.0    6-8   250.0
# 298                Tim Duncan    19    21.0        C  40.0   6-11   250.0
# 299             Manu Ginobili    19    20.0       SG  38.0    6-6   205.0
# 300               Danny Green    19    14.0       SG  28.0    6-6   215.0
# 301             Kawhi Leonard    19     2.0       SF  24.0    6-7   230.0
# 302          Boban Marjanovic    19    40.0        C  27.0    7-3   290.0
# 303              Kevin Martin    19    23.0       SG  33.0    6-7   199.0
# 304              Andre Miller    19    24.0       PG  40.0    6-3   200.0
# 305               Patty Mills    19     8.0       PG  27.0    6-0   185.0
# 306               Tony Parker    19     9.0       PG  34.0    6-2   185.0
# 307          Jonathon Simmons    19    17.0       SG  26.0    6-6   195.0
# 308                David West    19    30.0       PF  35.0    6-9   250.0
# 309             Kent Bazemore    20    24.0       SF  26.0    6-5   201.0
# 310          Tim Hardaway Jr.    20    10.0       SG  24.0    6-6   205.0
# 311              Kirk Hinrich    20    12.0       SG  35.0    6-4   190.0
# 312                Al Horford    20    15.0        C  30.0   6-10   245.0
# 313            Kris Humphries    20    43.0       PF  31.0    6-9   235.0
# 314               Kyle Korver    20    26.0       SG  35.0    6-7   212.0
# 315              Paul Millsap    20     4.0       PF  31.0    6-8   246.0
# 316              Mike Muscala    20    31.0       PF  24.0   6-11   240.0
# 317           Lamar Patterson    20    13.0       SG  24.0    6-5   225.0
# 318           Dennis Schroder    20    17.0       PG  22.0    6-1   172.0
# 319                Mike Scott    20    32.0       PF  27.0    6-8   237.0
# 455              Tibor Pleiss    29    21.0        C  26.0    7-3   256.0
# 456               Jeff Withey    29    24.0        C  26.0    7-0   231.0
# 457                       NaN    30     NaN      NaN   NaN    NaN     NaN
#
#                    College      Salary  Add
# 0                    Texas   7730337.0    4
# 1                Marquette   6796117.0    1
# 2        Boston University         NaN    1
# 3            Georgia State   1148640.0    3
# 4                      NaN   5000000.0    2
# 5                      NaN  12000000.0    3
# 6                      LSU   1170960.0    2
# 7                  Gonzaga   2165160.0    0
# 8               Louisville   1824360.0    0
# 9           Oklahoma State   3431040.0    0
# 10              Ohio State   2569260.0    0
# 11              Washington   6912869.0    1
# 12              Ohio State   3425510.0    2
# 13                Kentucky   1749840.0    2
# 14          North Carolina   2616975.0    2
# 15                     NaN   3425510.0    4
# 16          Oklahoma State    845059.0    1
# 17          North Carolina   1500000.0    0
# 18                 Arizona   1335480.0    0
# 19            Georgia Tech   6300000.0    4
# 20                     NaN   1599840.0    3
# 21              Cincinnati    134215.0    2
# 22              Miami (FL)   1500000.0    3
# 23                Stanford  19689000.0    2
# 24                Syracuse   1140240.0    1
# 25             Saint Louis    947276.0    2
# 26                  Kansas    981348.0    4
# 27              Georgetown    947276.0    1
# 28               Texas A&M    947276.0    0
# 29            Georgia Tech  11235955.0    2
# 30                    UCLA   8000000.0    0
# 31                    UNLV   1635476.0    3
# 32                     NaN     30888.0    1
# 33                Syracuse  22875000.0    0
# 34                     NaN   7402812.0    3
# 35           Wichita State    845059.0    2
# 36          Saint Joseph's    845059.0    4
# 37              Notre Dame   1572360.0    0
# 38                Stanford  12650000.0    1
# 39           Norfolk State   3750000.0    3
# 40                     NaN   4131720.0    4
# 41                     NaN   2814000.0    3
# 42                    Duke   1636842.0    2
# 43                     NaN    947276.0    3
# 44                 Arizona   4000000.0    0
# 45              Washington    167406.0    1
# 46                    Duke         NaN    4
# 47            Murray State    947276.0    3
# 48         Tennessee State   1000000.0    1
# 49                  Kansas   4626960.0    3
# 50                Syracuse    845059.0    0
# 51           Bowling Green   1074169.0    4
# 52                  Purdue   6500000.0    4
# 53          North Carolina   2144772.0    0
# 54                 Arizona    525093.0    1
# 55                Kentucky   3457800.0    4
# 56                    Duke   4582680.0    0
# 57             Wake Forest    947276.0    4
# 58                Michigan   2869440.0    0
# 59              Georgetown    947276.0    2
# 60                    UNLV    525093.0    3
# 61                     NaN   2814000.0    3
# 62                     NaN   1524000.0    3
# 63                Missouri  13600000.0    2
# 64                     USC  10050000.0    0
# 65             Wake Forest   2500000.0    0
# 66                   Texas   7000000.0    3
# 67               Villanova  12000000.0    3
# 68                     NaN   1842000.0    1
# 69                Kentucky   6268675.0    0
# 70                    UCLA    650000.0    1
# 71              Washington   3553917.0    2
# 72                     NaN   2900000.0    4
# 73                   Rider    245177.0    3
# 74                     NaN   4660482.0    2
# 75                    Utah   1509360.0    2
# 76                     NaN   2500000.0    2
# 77          North Carolina   3873398.0    3
# 78                    Utah  13800000.0    2
# 79                 Belmont    947276.0    1
# 80                Davidson  11370786.0    3
# 81              Vanderbilt   2008748.0    2
# 82          Michigan State  14260870.0    3
# 83                 Arizona  11710456.0    0
# 84                     NaN   5543725.0    3
# 85                    UCLA   1131960.0    2
# 86          North Carolina    845059.0    2
# 87                  Kansas   1270964.0    3
# 88                 Florida   3815000.0    2
# 89        Washington State  15501000.0    4
# 90                     NaN    289755.0    2
# 91                  Kansas   1100602.0    3
# 92           Arizona State    111444.0    3
# 93                Michigan   5675000.0    2
# 94          Michigan State    525093.0    2
# 95              Georgetown   9650000.0    1
# 96                Oklahoma  18907726.0    2
# 97                Syracuse   1100602.0    1
# 98               Texas A&M  19689000.0    4
# 99                    UCLA    947276.0    3
# 100            Wake Forest  21468695.0    1
# 101                 Kansas   3376000.0    3
# 102                    NaN    947726.0    3
# 103                   Duke   7085000.0    1
# 104                   Duke   3110796.0    0
# 105             Washington   1159680.0    4
# 106                    LSU   3000000.0    1
# 107                 Kansas    845059.0    3
# 108               Stanford    700000.0    3
# 109                    NaN  25000000.0    3
# 110               Missouri    845059.0    0
# 111             Georgetown  15592217.0    3
# 112                    NaN    525093.0    1
# 113                   Duke   1724250.0    4
# 114                Wyoming   1155600.0    1
# 115               Kentucky   3132240.0    0
# 116             Ohio State   5103120.0    1
# 117                Gonzaga    981348.0    3
# 118                    NaN   7000000.0    0
# 119             St. John's    947276.0    3
# 120                    USC   5219169.0    0
# 121               Kentucky  13500000.0    3
# 122               Kentucky   2127840.0    0
# 123                Arizona    206192.0    2
# 124                    NaN  13000000.0    3
# 125               Kentucky   1160160.0    1
# 126             Vanderbilt    981348.0    1
# 127               Kentucky  13500000.0    1
# 128               Maryland   3807120.0    4
# 129              Wisconsin   1035000.0    0
# 130               Missouri     55722.0    1
# 131            Utah Valley    947276.0    4
# 132                    NaN   5500000.0    3
# 133                  Texas   5500000.0    0
# 134   North Carolina State   2041080.0    1
# 135       UC Santa Barbara     83397.0    2
# 136                 Baylor    981348.0    2
# 137         Oklahoma State   1015421.0    4
# 138                    NaN   6060606.0    4
# 139            Connecticut   1449187.0    2
# 140                    NaN   2836186.0    3
# 141               Kentucky   3398280.0    2
# 142                   UCLA   5013559.0    0
# 143               Kentucky  15851950.0    3
# 144                   Duke    947276.0    4
# 145              Wisconsin    525093.0    4
# 146            Connecticut  12403101.0    4
# 147             Ohio State   7700000.0    1
# 148                 Kansas   3156600.0    4
# 149           Oregon State    845059.0    2
# 150               Kentucky   9500000.0    4
# 151             New Mexico    845059.0    2
# 152                 Oregon   2250000.0    4
# 153              Marquette  16407500.0    1
# 154                   Duke   4500000.0    2
# 155                    NaN    525093.0    4
# 156                    NaN   7448760.0    0
# 157                    USC   8500000.0    2
# 158             Washington    947276.0    0
# 159              Creighton   2380440.0    4
# 160                    NaN   5543725.0    1
# 161                 Purdue   1015421.0    0
# 162                Florida  13400000.0    2
# 163               Arkansas   1391160.0    0
# 164                Memphis  20093064.0    2
# 165             New Mexico   1535880.0    2
# 166           Saint Mary's   1147276.0    1
# 167                Arizona   8193029.0    0
# 255                    NaN    947276.0    1
# 256                Arizona    947276.0    0
# 257                   UCLA   1404600.0    3
# 258         Oklahoma State   5158539.0    2
# 259          Blinn College   5000000.0    2
# 260                   UCLA   3542500.0    0
# 261         North Carolina   4088019.0    2
# 262             Ohio State   9588426.0    1
# 263             Providence    700902.0    2
# 264                   UCLA         NaN    1
# 265                    NaN  19688000.0    0
# 266                Alabama    845059.0    2
# 267         North Carolina   1201440.0    3
# 268                    LSU   1230840.0    0
# 269                Detroit         NaN    1
# 270           Rhode Island         NaN    3
# 271         Michigan State   9638555.0    0
# 272             Cincinnati   9000000.0    2
# 273                    USC         NaN    0
# 274         North Carolina   5464000.0    2
# 275                    NaN   4389607.0    4
# 276             California   8500000.0    0
# 277                    NaN   9213483.0    4
# 278                 Nevada   1100602.0    2
# 279        Cleveland State   3036927.0    2
# 280              Villanova   2850000.0    4
# 281               Kentucky   7070730.0    3
# 282             Iowa State    169883.0    4
# 283          Florida State   1164858.0    0
# 284       Long Beach State    845059.0    4
# 285                Memphis  10734586.0    1
# 286             Penn State    845059.0    2
# 287                Alabama   1320000.0    3
# 288                Indiana  15514031.0    1
# 289                  Texas   1015421.0    1
# 290                   UCLA  10595507.0    3
# 291       UC Santa Barbara     55722.0    1
# 292                    NaN    947276.0    3
# 293             Washington   3382023.0    1
# 294                  Texas  19689000.0    1
# 295                   UCLA   1142880.0    0
# 296                Florida    947276.0    0
# 297                    NaN   7500000.0    4
# 298            Wake Forest   5250000.0    4
# 299                    NaN   2814000.0    4
# 300         North Carolina  10000000.0    2
# 301        San Diego State  16407500.0    1
# 302                    NaN   1200000.0    3
# 303       Western Carolina    200600.0    3
# 304                   Utah    250750.0    2
# 305           Saint Mary's   3578947.0    2
# 306                    NaN  13437500.0    2
# 307                Houston    525093.0    3
# 308                 Xavier   1499187.0    4
# 309           Old Dominion   2000000.0    3
# 310               Michigan   1304520.0    1
# 311                 Kansas   2854940.0    1
# 312                Florida  12000000.0    4
# 313              Minnesota   1000000.0    0
# 314              Creighton   5746479.0    1
# 315         Louisiana Tech  18671659.0    3
# 316               Bucknell    947276.0    4
# 317             Pittsburgh    525093.0    0
# 318                    NaN   1763400.0    0
# 319               Virginia   3333333.0    2
# 320                    NaN   4000000.0    3
# 321                    NaN   9756250.0    4
# 322                    NaN   1000000.0    4
# 323            Wake Forest   8000000.0    0
# 324                    NaN  13125306.0    0
# 325  Virginia Commonwealth    947276.0    4
# 326             California    189455.0    2
# 327         North Carolina    947276.0    4
# 328               Kentucky    525093.0    3
# 329             Washington   6110034.0    0
# 330                    NaN  13500000.0    0
# 331              Wisconsin   2612520.0    1
# 332               Kentucky   6331404.0    1
# 333            Connecticut   3034356.0    1
# 334       Western Kentucky   5675000.0    1
# 335                Harvard   2139000.0    0
# 336            Connecticut  12000000.0    2
# 337         North Carolina   7000000.0    2
# 338                Indiana   4204200.0    3
# 339           Georgia Tech  22192730.0    4
# 340                   Duke  10151612.0    4
# 341                    NaN  14783000.0    2
# 342                    NaN    947276.0    0
# 343                Florida   2854940.0    4
# 344               Arkansas    261894.0    2
# 345           Fresno State    845059.0    3
# 346                   Duke   5543725.0    0
# 347              Tennessee    525093.0    4
# 348                    NaN    947276.0    0
# 349              Marquette  20000000.0    4
# 350  Virginia Commonwealth         NaN    4
# 351               Marshall    981348.0    3
# 352                   Duke   2481720.0    0
# 353                    NaN         NaN    0
# 354                    USC    947276.0    0
# 355                    NaN   2288205.0    1
# 356                Arizona   4171680.0    2
# 357                    NaN   3741480.0    2
# 358                    NaN   7900000.0    1
# 359                    NaN   8344497.0    4
# 360                   Iowa    845059.0    0
# 361            Connecticut   1294440.0    2
# 362        St. Bonaventure   2380593.0    3
# 363                Indiana   5192520.0    0
# 364    Louisiana-Lafayette   2505720.0    1
# 365         Colorado State   4300000.0    3
# 366                    USC  11250000.0    2
# 367              Tennessee   5000000.0    2
# 368         Michigan State   4000000.0    0
# 369                Florida   5694674.0    1
# 370         Boston College   4375000.0    4
# 371          Virginia Tech    561716.0    4
# 372                 Kansas   3300000.0    4
# 373                    NaN  11217391.0    4
# 374   North Carolina State    273038.0    2
# 375                    NaN  13000000.0    2
# 376                 Kansas   8000000.0    1
# 377                 Kansas   1920240.0    0
# 378             Georgetown   4662960.0    0
# 379                 Nevada   2170465.0    1
# 380                    LSU   1100602.0    2
# 381                    LSU    200600.0    3
# 382               Kentucky  15851950.0    0
# 383                 Kansas   2814000.0    1
# 384                  Texas   3000000.0    3
# 385                Memphis   3533333.0    4
# 386                 DePaul  10449438.0    3
# 387         Morehead State  11235955.0    1
# 388                    NaN  14000000.0    3
# 389         Michigan State   1584480.0    1
# 390                    NaN   1300000.0    1
# 391                    NaN   1709719.0    1
# 392                Florida    947276.0    1
# 393                    NaN   3102240.0    0
# 394         Saint Joseph's   4345000.0    1
# 395                    NaN   1842000.0    3
# 396             St. John's    258489.0    1
# 397                    NaN         NaN    4
# 398                    NaN   3950001.0    2
# 399             Louisville   1474440.0    1
# 400                    NaN   8500000.0    3
# 401                   Duke   1282080.0    0
# 402                   UCLA   2148360.0    3
# 403                   UCLA   2056920.0    0
# 404         Michigan State   1938840.0    3
# 405                    NaN  12100000.0    3
# 406               Kentucky    947276.0    3
# 407                    NaN  12700000.0    4
# 408                    NaN   1149500.0    4
# 409           Fresno State         NaN    3
# 410               Kentucky   5703600.0    0
# 411                 Kansas   5758680.0    1
# 412             Pittsburgh   2279040.0    2
# 413                 Kansas   3750000.0    2
# 414                  Texas  20158622.0    1
# 415              Villanova   3135000.0    1
# 416               Stanford   1140240.0    4
# 417                    NaN  12250000.0    3
# 418               Kentucky  16407500.0    2
# 419               Michigan   1463040.0    1
# 420               Kentucky    222888.0    3
# 421           Georgia Tech   3344000.0    1
# 422           Murray State   2021520.0    3
# 423               Colorado   1210800.0    1
# 424                   Duke   4500000.0    1
# 425               Syracuse   5138430.0    4
# 426                   UCLA  16744218.0    1
# 427                 Kansas    525093.0    0
# 428            Wake Forest   8042895.0    3
# 429             Notre Dame    625093.0    4
# 430             California    947276.0    1
# 431         North Carolina   6980802.0    2
# 432             St. John's   2894059.0    4
# 433                   Duke   6000000.0    1
# 434       Central Michigan   5016000.0    1
# 435               Illinois   3075880.0    1
# 436            Weber State   4236287.0    3
# 437                 Lehigh   2525160.0    0
# 438         Westchester CC    525093.0    3
# 439                   Duke   1415520.0    1
# 440                 Dayton   2854940.0    0
# 441                Indiana   2637720.0    2
# 442                Clemson   4775000.0    3
# 443               Michigan   2658240.0    0
# 444               Colorado   9463484.0    3
# 445                    NaN   3777720.0    1
# 446           Georgia Tech  12000000.0    1
# 447                    NaN   1175880.0    0
# 448                 Butler  15409570.0    3
# 449                   Duke   1348440.0    3
# 450                    NaN   2050000.0    0
# 451                 Dayton    981348.0    2
# 452               Kentucky   2239800.0    3
# 453                 Butler   2433333.0    4
# 454                    NaN    900000.0    3
# 455                    NaN   2900000.0    0
# 456                 Kansas    947276.0    0
# 457                    NaN         NaN    1

# %%
# select a specific value from a certain column
# find the Team 2 : "Brooklyn Nets" 
# we didn't use inplace = True in the previous module, if you use the "nba" dataset, there is no team names 2
nba_replace.loc[nba_replace['Team'] == 2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-c5ef2a36f2ce> in <module>
#       2 # find the Team 2 : "Brooklyn Nets"
#       3 # we didn't use inplace = True in the previous module, if you use the "nba" dataset, there is no team names 2
# ----> 4 nba_replace.loc[nba_replace['Team'] == 2]
#
# NameError: name 'nba_replace' is not defined

# %%
#Calculate the mean/median value
mean_Sal=nba["Salary"].mean() #.median()
mean_Sal

# %%
# rounded off
round((nba["Salary"].mean()),0)

# %%
# Round to specific decimal 
round((nba["Salary"].mean()),2)

# %%
#Calculate the total salary for all the people in the nba dataset
sum_Sal = nba["Salary"].sum()
sum_Sal

# %% [markdown]
# ## Texts Cleaning

# %% [markdown]
# ### Pandas functions for text mining
#
# **S.No**	**Function**	**Description**
# 1. **lower()**	Converts strings in the Series/Index to lower case.
# 2. **upper()**	Converts strings in the Series/Index to upper case.
# 3. **len()**	Computes String length().
# 4. **strip()**	Helps strip whitespace(including newline) from each string in the Series/index from both the sides.
# 5. **split(' ')**	Splits each string with the given pattern.
# 6. **cat(sep=' ')**	Concatenates the series/index elements with given separator.
# 7. **get_dummies()**	Returns the DataFrame with One-Hot Encoded values.
# 8. **contains(pattern)**	Returns a Boolean value True for each element if the substring contains in the element, else False.
# 9. **replace(a,b)**	Replaces the value a with the value b.
# 10. **repeat(value)**	Repeats each element with specified number of times.
# 11. **count(pattern)**	Returns count of appearance of pattern in each element.
# 12. **startswith(pattern)**	Returns true if the element in the Series/Index starts with the pattern.
# 13. **endswith(pattern)**	Returns true if the element in the Series/Index ends with the pattern.
# 14. **find(pattern)**	Returns the first position of the first occurrence of the pattern.
# 15. **findall(pattern)**	Returns a list of all occurrence of the pattern.
# 16. **swapcase**	Swaps the case lower/upper.
# 17. **islower()**	Checks whether all characters in each string in the Series/Index in lower case or not. Returns Boolean
# 18. **isupper()**	Checks whether all characters in each string in the Series/Index in upper case or not. Returns Boolean.
# 19. **isnumeric()**	Checks whether all characters in each string in the Series/Index are numeric. Returns Boolean.
#
# Source: https://www.tutorialspoint.com/python_pandas/python_pandas_working_with_text_data.htm

# %%
# Action 4: open the sampletweets2022.csv and name it as dftweets
dftweets =

# %%
# Action 5: display the first 5 rows

# %%
# Action 6: display the dataframe basic information

# %%
# display all the columns names
print(dftweets.columns)

# %%
# Action 7: display all the information (hints: set_options())

# %%
# Action 8: show the generate descriptive statistics

# %%
# Action 9: rename columns (hints: 0 (first column) to user; 1 to tweet) (columns={0: 'user', 1: 'tweet'})

# %%
# lower case usernames
dftweets['user'].str.lower()
dftweets['user']

# %%
# above fuction dosen't work
# Lower case tweets with function and Apply
def textLower(x):
    return x.lower()

# %%
dftweets['user'].apply(textLower)

# %%
# upper case usernames
dftweets['user'].str.upper()
dftweets['user']

# %%
# Action 10: write a textUpper fuction and apply it to the usernames

# %%
# save and change it in the original dataset
dftweets['user'] = dftweets['user'].apply(textLower)

# %%
dftweets.head()

# %%
# Get the number of characters in each tweet
dftweets['tweet'].str.len()

# %%
# Action 11: add a new column and name is "count_text" to store the number of character in each tweet

# %%
# find the words starts with... hashtags
dftweets.tweet.str.findall("(?<=#)\w+")

# %%
# Action 12: Create a column named "hashtags"

# %%
#find all the words starting with @ (mentions in Twitter)
dftweets.tweet.str.findall("(?<=@)\w+")

# %%
# Action 13: Create a column named "mentions"

# %%
# Action 14: what is the data type of the values in columns "hashtags" and "mentions"?

# %%
# remove the brackets and keep the string values
dftweets['hash_str'] = dftweets['hashtags'].apply(', '.join)

# %%
# Action 15: remove the brackets and keep the string values for column "mentions"

# %%
# tokenization
dftweets['tweet'].str.split()

# %%
# Determine the number of words in each tweet and create a column "wordcount"
dftweets['wordcount'] = dftweets['tweet'].str.split().str.len()
dftweets.head()

# %%
# How many hashtags per each tweet?
dftweets.tweet.str.count('#')

# %%
# Action 16: Find the number of mentions in each tweet

# %%
# check a string (#KState) in the data using boolean indexing
dftweets.tweet.str.contains("#KState")

# %%
# check a string contains either A or B and view the results
ka = dftweets.tweet.str.contains("#KState|#aggieville")
dftweets[ka]

# %%
# contains both A and B
dftweets[(dftweets['tweet'].str.contains('#KState')) & (dftweets['tweet'].str.contains('#aggieville'))]

# %%
# View retweets only (tweets contains RT)
retweets = dftweets.tweet.str.contains("RT")
dftweets[retweets]

# %%
# View retweets only (tweets start with RT)
dftweets.tweet.str.startswith("RT")

# %%
# view tweets do not contain RT (original tweets)
new_dftweets = dftweets[~dftweets["tweets"].str.contains("RT")]

# %%
# Action 17: remove all the symbols from the tweets hints:re.sub(r"[^a-zA-Z0-9]+",' ',text)

# %%
# same results without library re
dftweets['tweet'].str.replace(r'[^a-zA-Z0-9]+', ' ')

# %%
# Action 18: remove http links hints:replace('http\S+|www.\S+', '')

# %%
# Action 19: remove numbers hints:replace('\d+', '')

# %%
# Action 20: Remove both mentions and hashtags from tweets

# %%
# Action 21: safe the cleaned tweets to a new column and name it "cleaned_tweet"
