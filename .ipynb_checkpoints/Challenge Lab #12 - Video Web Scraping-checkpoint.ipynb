# %% [markdown]
# # Example: Scrape YouTube data (API)

# %% [markdown]
# Using API: Legal, fast, easy, full information

# %% [markdown]
# **Apply a YouTube Data API v3:**
#
# 1. Create a Google account (skip this step if you already have one).
# 2. Open Google developer console https://console.cloud.google.com
# 3. Click the dropdown menu on the top left beside "Google Cloud". In the popup window click `NEW PROJECT` to create a project (you don't have to select the organization).
# 4. Click `APIs & Services` from the side menu.
# 5. Click `Enable APIs and Services` (on the top menu with a + ).
# 6. Scroll down to find `YouTube Data API v3`.
# 7. Click `Enable`.
# 8. The page will automatically take you to another page, click `Credentials` on the left side menu.
# 9. You can always find your API key from the Credentials.
# 10. If you don't see you API there, in the Credentials page, click `+ Create Credentials` , select API key, then you can get a new one. Copy this key to this Jupyter Notebook.

# %% [markdown]
# ## Example 1: Scrape YouTube Comments

# %% [markdown]
# Intall packages and import libraries
#
# ! pip install urllib3
#
# conda install -c anaconda urllib3
#
# https://anaconda.org/anaconda/urllib3
#
#
#
# ! pip install google_auth_oauthlib
#
# conda install -c conda-forge google-auth-oauthlib
#
# https://anaconda.org/conda-forge/google-auth-oauthlib
#
#
#
# ! pip install google-api-python-client
#
# conda install -c conda-forge google-api-python-client
#
# https://anaconda.org/conda-forge/google-api-python-client

# %%
# Libraries
import pandas as pd
import time
import json
from urllib.request import urlopen
from googleapiclient.discovery import build

# %% [markdown]
# **To create the url (video id list) from your search on YouTube:**
#
# 1. Open https://developers.google.com/youtube/v3/docs/search/list
# 2. Maximize your window size.
# 3. On the right side, there is a `Try this method` window panel.
# 4. Click the maximize window size button "[]" The square next to the close sign.
# 5. Set your search conditions
#     - q: for search keywords or phrases
# 6. Once you setup the conditions, click `EXECUTE`
# 7. If the right bottom console displays `200` with a green bar, your url is generated and the search is successful.
# 8. Copy the url on the right top window start with "https://" to the following module.
#     - For example: https://youtube.googleapis.com/youtube/v3/search?maxResults=50&q=data%20science&key=[YOUR_API_KEY]
# 9. Replace [YOUR_API_KEY] with you API key, removing the brackets.
#     - For example: https://youtube.googleapis.com/youtube/v3/search?maxResults=50&q=data%20science&key=AIzaSyD8eJx2sUHuN6n3AGn15bmKfcEtLQ67YT0
# 10. You can check this url just click the link and see the json data in a browser window.

# %%
# get the url from https://developers.google.com/youtube/v3/docs/search/list?apix=true&apix_params=%7B%22maxResults%22%3A50%2C%22order%22%3A%22date%22%2C%22q%22%3A%22hurricane%20ian%22%7D#parameters
# Try this API using parameters
url = "https://youtube.googleapis.com/youtube/v3/search?maxResults=50&q=data%20science&key=AIzaSyD8eJx2sUHuN6n3AGn15bmKfcEtLQ67YT0"
  
# store the response of URL
response = urlopen(url)
  
# storing the JSON response 
# from url in data
data_json = json.loads(response.read())

# print the json response
print(json.dumps(data_json, indent=4))
# Out:
# {
#     "kind": "youtube#searchListResponse",
#     "etag": "3PIGvXcOtJ2bNotRJN7sVMORe5w",
#     "nextPageToken": "CDIQAA",
#     "regionCode": "US",
#     "pageInfo": {
#         "totalResults": 1000000,
#         "resultsPerPage": 50
#     },
#     "items": [
#         {
#             "kind": "youtube#searchResult",
#             "etag": "I8EhfFKbhot4XoKJvGSbQgJlUlg",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "X3paOmcrTjQ"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "zkeluh9ioQpbbPSJY6-wmeP7CxI",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "RBSUwFGa6Fk"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "PiU4CJVbEt7PiwO9usat1JzYjvE",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "xC-c7E5PK0Y"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "DXv1-NdL7T2HPXRfHfIXlRwyf3A",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "ua-CiDNNj30"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "g_82o1rsr6dWvEJZqkh-7_CUntQ",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "-ETQ97mXXF0"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "8B3gDjQRgYPyohDdMbZIafBQTrw",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "pn0PUY0jwGQ"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "o6i7iOMAkpQrbREUYlHUzeFJjIU",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "xvEKQefqQ7A"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "FPDQarqKvq61eNuLsV4U0Hb9AN0",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "sOZ8MxFw8TQ"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "UHozc3xYpduFC0_8ITKistWmHSA",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "uswU1s3M2VE"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "r7wnS1adEgyehn3qHpOsxxILZBU",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "O9nf1CqjGzI"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "VeLg_esnweEjdCNwBboEBbqezSI",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "fUpChfNN5Uo"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "-0PhfA-wuevjgm7mzrECd8LAAeM",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "Rt6eb9VOFII"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "kbPNZ_Mm_uuSPxioZHl9z1OfrOs",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "iJUzouXg5kY"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "ffch9pe1-AefB6finGMXD215sdE",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "5O9abIxIqNA"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "334-xOVrkJhW9t4LRClAttjCkaI",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "xpIFS6jZbe8"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "jistXXQKKglui-be6BEe-Zs7s_c",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "OybXWl3IWvI"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "_U7hGpKk2zbz4QjJYjYiXkk-nzk",
#             "id": {
#                 "kind": "youtube#channel",
#                 "channelId": "UCEBpSZhI1X8WaP-kY_2LLcg"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "dEbLRJ22TeO6S_N0jtU6pL0LjIE",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "J68XETxye7g"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "G9FIZ8_LOywx1mGjtoJgwnfmDBs",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "N6BghzuFLIg"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "onwaJFZqROwQT3af3qOXnQetMog",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "rqvyWUODZGE"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "2PWEU9osgjkTN7DwnTPE3eqM4RM",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "LHBE6Q9XlzI"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "5EfZuSqDlyiD1-oDNEFxgGQcQYA",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "oMn8zc5NlL4"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "NX2cppXcOfMfd40M_aDIYGU2MwI",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "iPdO9MwdcLE"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "-ImcfHCFgYnmfX9gtafGB7BLdwo",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "71RVNeseKZw"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "nf5EKMclN1YVNEJsnwCcwBvXwk4",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "AI1eKN1Eldg"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "M-eeg2iVgNry4TAezItscHy7v0g",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "AYWLZ1lES6g"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "ieqXs5EJWfHGIwKUlZpnSTKL8EA",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "sHRq-LshG3U"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "phxeoCVFRZUZV_OhaztYmvkQoLc",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "Axu4tJl8gbM"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "GyXsoX9gcq6UePpk4Lobk_zp-5s",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "7eh4d6sabA0"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "7PN-X7F3MrmHS8lPFz1ksuRtM-4",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "DoFZtsV25Zw"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "51YqzgvEXQgXYimRpgXAU1fpc0g",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "ylOILe-Sc-w"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "CNjf8q58Gb65sQ-5dxWnF71b8G8",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "PNr51ZJkoBU"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "gF1R-O5z0kzwS3voZ9MRibPwbzg",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "nLPve1gGSMU"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "jP2-xu2XpCbCNQsIC0ArjwKrXvs",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "eJtHzkMy_1k"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "I1WTYhlrPx0bw47PZuE2CB_JxJU",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "A2v4_SFd9Cc"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "wTKV6Z8W9b0ifmao88NAxBZuCiY",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "jtn-hRJjl68"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "8zvlYDFh_zLIE2I5R1RYrmMbzJI",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "JUkSeqe1eYQ"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "-mUFbq_AlDXLZzGvKe9hMWOwCRA",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "gamjNp2CToQ"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "PibsIFRlulKTvMPVa8cy1M-6sWo",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "rLvpY2v9hWQ"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "CrepJTMRZGRf6dj_M4yYGT6Hc7o",
#             "id": {
#                 "kind": "youtube#playlist",
#                 "playlistId": "PLeo1K3hjS3us_ELKYSj_Fth2tIEkdKXvV"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "xXVQzMK44tg7ChxKQ8gSijx2ue8",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "FvGRKQipTP8"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "IuKcpycPKuQVBSPqKGho4vHaq3Q",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "65yXoFc5stI"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "RJXrA6qGgGQ6qF4Gf7P_7zPaWTs",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "Zoc9USYVdWM"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "PqLE1mLGvoDnHqI9waomcRQKq-g",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "csG_qfOTvxw"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "Q8krWKnB6FaleF1B2axx5cd5YgU",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "QMP858aZcow"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "9R5-D8Fk9R_VX43Z_TiZNvgNbMQ",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "pzo13OPXZS4"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "GIWxwfVBdXHpaqi9Stz2VcNB-k4",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "4Z6lxfglvUU"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "Hl9qNasD8qtZKznH1rbREIIkNS4",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "XW0YptcgZSk"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "ADhaRz5Ou_TGVAufmFxQfM-QvBg",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "qrhRfPY4F4w"
#             }
#         },
#         {
#             "kind": "youtube#searchResult",
#             "etag": "24ozeGInat_ysJ6AiUzFkzLIvRw",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "Fr1kMa10kxo"
#             }
#         }
#     ]
# }

# %%
# find out the video id and store the etags as well
youtubedf = pd.json_normalize(data_json, 'items', errors='ignore')
youtubedf = youtubedf.drop(columns=['kind', 'id.kind'])
youtubedf.head()
# Out:
#                           etag   id.videoId id.channelId id.playlistId
# 0  I8EhfFKbhot4XoKJvGSbQgJlUlg  X3paOmcrTjQ          NaN           NaN
# 1  zkeluh9ioQpbbPSJY6-wmeP7CxI  RBSUwFGa6Fk          NaN           NaN
# 2  PiU4CJVbEt7PiwO9usat1JzYjvE  xC-c7E5PK0Y          NaN           NaN
# 3  DXv1-NdL7T2HPXRfHfIXlRwyf3A  ua-CiDNNj30          NaN           NaN
# 4  g_82o1rsr6dWvEJZqkh-7_CUntQ  -ETQ97mXXF0          NaN           NaN

# %%
youtubedf.shape
# Out:
# (50, 4)

# %%
## The url (search) is changing everyday/every search. It returns the most recent videos (max 50) for a search.
# save your videoID to a csv file for future use
# you can search the comments based on the videoID from the csv 
youtubedf.to_csv("DS1004YT_VID.csv")

# %%
# get the YouTube credentials
API_KEY = "AIzaSyD8eJx2sUHuN6n3AGn15bmKfcEtLQ67YT0"
youtube = build ('youtube','v3',developerKey = API_KEY)

# %%
dir(youtube)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_basic_methods',
#  '_add_nested_resources',
#  '_add_next_methods',
#  '_baseUrl',
#  '_developerKey',
#  '_dynamic_attrs',
#  '_http',
#  '_model',
#  '_requestBuilder',
#  '_resourceDesc',
#  '_rootDesc',
#  '_schema',
#  '_set_dynamic_attr',
#  '_set_service_methods',
#  'abuseReports',
#  'activities',
#  'captions',
#  'channelBanners',
#  'channelSections',
#  'channels',
#  'close',
#  'commentThreads',
#  'comments',
#  'i18nLanguages',
#  'i18nRegions',
#  'liveBroadcasts',
#  'liveChatBans',
#  'liveChatMessages',
#  'liveChatModerators',
#  'liveStreams',
#  'members',
#  'membershipsLevels',
#  'new_batch_http_request',
#  'playlistItems',
#  'playlists',
#  'search',
#  'subscriptions',
#  'superChatEvents',
#  'tests',
#  'thirdPartyLinks',
#  'thumbnails',
#  'videoAbuseReportReasons',
#  'videoCategories',
#  'videos',
#  'watermarks',
#  'youtube']

# %%
# read the videoId from the saved csv
YTdf = pd.read_csv("DS1004YT_VID.csv")
YTdf.head()
# Out:
#    Unnamed: 0                         etag   id.videoId id.channelId  \
# 0           0  I8EhfFKbhot4XoKJvGSbQgJlUlg  X3paOmcrTjQ          NaN
# 1           1  zkeluh9ioQpbbPSJY6-wmeP7CxI  RBSUwFGa6Fk          NaN
# 2           2  PiU4CJVbEt7PiwO9usat1JzYjvE  xC-c7E5PK0Y          NaN
# 3           3  DXv1-NdL7T2HPXRfHfIXlRwyf3A  ua-CiDNNj30          NaN
# 4           4  g_82o1rsr6dWvEJZqkh-7_CUntQ  -ETQ97mXXF0          NaN
#
#   id.playlistId
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# get the YouTube comments for each video using youtube.commentThreads().list(part="snippet", videoId=vid)
# multiple nested json data
for vid in YTdf["id.videoId"][:1]:
    request = youtube.commentThreads().list(part="snippet", videoId=vid)
    response = request.execute()
    print(json.dumps(response, indent=4))
# Out:
# {
#     "kind": "youtube#commentThreadListResponse",
#     "etag": "2NRtafYLyKoyCTwaUfbGGtoIMdo",
#     "nextPageToken": "QURTSl9pMGRnQVNYbFVXRTgwMEpYMndXMlgydl9fVnJwVmNFeW5NWFdodk5QaXJEY0kzeFRlekpZOUlBTVo0TnpHdHd4MVVCbnk0SFp5dWVjWTFOV0lFR0JxRkNINTYwRlE=",
#     "pageInfo": {
#         "totalResults": 20,
#         "resultsPerPage": 20
#     },
#     "items": [
#         {
#             "kind": "youtube#commentThread",
#             "etag": "y86llHFPHtjBdLgQ_ohH9gvtNBA",
#             "id": "UgxvUkmSK9q2mnPHAuZ4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "DBB88ytp1Y3Cu9CCT1VCrPMa-YQ",
#                     "id": "UgxvUkmSK9q2mnPHAuZ4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "\ud83d\udd25Explore Our FREE Courses With Completion Certificate: <a href=\"https://www.youtube.com/watch?v=-caxhMlw_04\">https://www.youtube.com/watch?v=-caxhMlw_04</a>",
#                         "textOriginal": "\ud83d\udd25Explore Our FREE Courses With Completion Certificate: https://www.youtube.com/watch?v=-caxhMlw_04",
#                         "authorDisplayName": "Simplilearn",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu9vk_jSZZqpKOw6TohZDkc4e2ekKVYPlcioQjttfQ=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCsvqVGtbbyHaMoevxPAq9Fg",
#                         "authorChannelId": {
#                             "value": "UCsvqVGtbbyHaMoevxPAq9Fg"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 43,
#                         "publishedAt": "2021-09-02T18:04:08Z",
#                         "updatedAt": "2021-09-02T18:04:08Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 4,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "16M5IlA8kSMbdXJ2JSJWvWvpBXI",
#             "id": "UgwIqSnkVJX2r5L8uTB4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "a3h0AUB3Ywh2dFT-TsSsxCsnNWY",
#                     "id": "UgwIqSnkVJX2r5L8uTB4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "<b>This was NOT helpful at all! I have no idea what a Data Scientist is..and you assumed people like myself would know the terms you used or how it is applied in business scenarios. I came here to learn..but you created a video for people who already know the basics of data science and how it is applied..which means this was NOT a video for beginners. This doesn&#39;t make me want to watch any more of your videos since you did such a poor job here!</b> \u2639\ud83d\udc4e",
#                         "textOriginal": "*This was NOT helpful at all! I have no idea what a Data Scientist is..and you assumed people like myself would know the terms you used or how it is applied in business scenarios. I came here to learn..but you created a video for people who already know the basics of data science and how it is applied..which means this was NOT a video for beginners. This doesn't make me want to watch any more of your videos since you did such a poor job here!* \u2639\ud83d\udc4e",
#                         "authorDisplayName": "Nightbird",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/XbE-hPXHwWeYip09NgmngQO4W7bQ5sFTAnnRT-yNJl9EiBg4eJhpqJ8QjyyDi2yUsAzCLA4rjw=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCkzrrYMaT5O9s-76qvKRDxg",
#                         "authorChannelId": {
#                             "value": "UCkzrrYMaT5O9s-76qvKRDxg"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-08-13T18:11:01Z",
#                         "updatedAt": "2022-08-13T18:11:01Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 0,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "BUdITpJa7o75S1mXteNfhzv3Drg",
#             "id": "UgxDnm-NUVoFFqWV_jp4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "iuaA7EsdS6SH8U-eZXIjeSWTCA0",
#                     "id": "UgxDnm-NUVoFFqWV_jp4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "I am thinking to take cse with data science in NSUT :)... btw thanks \ud83d\ude0a",
#                         "textOriginal": "I am thinking to take cse with data science in NSUT :)... btw thanks \ud83d\ude0a",
#                         "authorDisplayName": "Sayan Mondal",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu_-B-kRmP5HtfqRFfie00NWMF7k-27BKOv0dXGwMg=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCtkuXL-WSFKYuvpWLa49bsg",
#                         "authorChannelId": {
#                             "value": "UCtkuXL-WSFKYuvpWLa49bsg"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-08-11T18:25:04Z",
#                         "updatedAt": "2022-08-11T18:25:04Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "uhpzFrbvgSaBHXyUKNSV5PlYz6U",
#             "id": "UgyJjviDA6gwuYiETod4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "EwEQP0goC0ldMd84MqYKj1Y_R7I",
#                     "id": "UgyJjviDA6gwuYiETod4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "Is the salary monthly or annual?",
#                         "textOriginal": "Is the salary monthly or annual?",
#                         "authorDisplayName": "aryan puri",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu-Tr4vTTChhSrCoNKXdWupZpJK2wR7zuCGIsg=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCHWEjQjQgPltdbTDVTO-qBA",
#                         "authorChannelId": {
#                             "value": "UCHWEjQjQgPltdbTDVTO-qBA"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 0,
#                         "publishedAt": "2022-07-05T11:12:44Z",
#                         "updatedAt": "2022-07-05T11:12:44Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "BC9iMUuTSW7nQ3_q51qBC9nEgC8",
#             "id": "UgxvkkEMm1Xe7ut_60l4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "gw9A71j00IIZatBoFMNQuVqDpq0",
#                     "id": "UgxvkkEMm1Xe7ut_60l4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "Captions, please. Thank you in advance!",
#                         "textOriginal": "Captions, please. Thank you in advance!",
#                         "authorDisplayName": "Slow Down Cooking",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/jROB_63_ZLowFZATevx7735cXPLPVNQd-xQSBryGRc44UIf9_yH9fuh80hNf_GWVamR_X4rL5g=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCFTFCadazGjRtJwh4neDsCg",
#                         "authorChannelId": {
#                             "value": "UCFTFCadazGjRtJwh4neDsCg"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-07-03T09:15:02Z",
#                         "updatedAt": "2022-07-03T09:15:02Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "C1sVstM7Igicmqx2tfr0Aw2oOWI",
#             "id": "UgxeJ0ZKCjkH7n3nCgF4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "jasRh4oYir3IjfZ7_mC_eNHMAUI",
#                     "id": "UgxeJ0ZKCjkH7n3nCgF4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "I want to learn",
#                         "textOriginal": "I want to learn",
#                         "authorDisplayName": "Godwin Jackson",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu9qwJZoFBFpCRV_ZgZnbm0D_P21y8W-T9kKZDCrDQ=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCHnufviYb9EfonVMtfvzzYg",
#                         "authorChannelId": {
#                             "value": "UCHnufviYb9EfonVMtfvzzYg"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-06-23T16:08:18Z",
#                         "updatedAt": "2022-06-23T16:08:18Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "FzxN5mLUKB8P0_NEZ5sihMar5VU",
#             "id": "UgzuT9EAJqj19n-lXtd4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "hLJU05HrWJ4qAKWYSN5TNfu0-lA",
#                     "id": "UgzuT9EAJqj19n-lXtd4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "Good job.",
#                         "textOriginal": "Good job.",
#                         "authorDisplayName": "\u0110\u1ed9 Dollars",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu-OPafqEbKVo5zF-1cLZ_d1g07caqXIRiIt2PcTuwU=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCyDIRJ8v5SwVE3bYNKEH4SA",
#                         "authorChannelId": {
#                             "value": "UCyDIRJ8v5SwVE3bYNKEH4SA"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-06-14T16:08:00Z",
#                         "updatedAt": "2022-06-14T16:08:00Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "Xmr7jOKV6_tCUJ4NBZFYgv2sgUs",
#             "id": "UgzImXH9I1vGlCMLWO14AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "OJzOmIe4usijwOBJ8AnM6_34sY0",
#                     "id": "UgzImXH9I1vGlCMLWO14AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "It&#39;s my dream to become a data scientist...<br>Thank for sharing this information \u263a\ufe0f",
#                         "textOriginal": "It's my dream to become a data scientist...\nThank for sharing this information \u263a\ufe0f",
#                         "authorDisplayName": "MIRL7",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu-BF4VWPREl5fXZ5ndoiSjdplXQH29BXmVn9zB5DY6-kypxUJ3L2Z1ovA56waPq=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCMgcsVXU4b_5xYLpAjjyuig",
#                         "authorChannelId": {
#                             "value": "UCMgcsVXU4b_5xYLpAjjyuig"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-05-24T16:12:12Z",
#                         "updatedAt": "2022-05-24T16:12:12Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "XGgZPDQCnyGUs7zlDJ46Hp_nzHI",
#             "id": "UgyAgZHGGDIs4qfgL954AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "560q-hUKL1gUkNvroyu2q7m0Zpw",
#                     "id": "UgyAgZHGGDIs4qfgL954AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "i have no knowledge about coding or anything .is it safe to enter into this course ?",
#                         "textOriginal": "i have no knowledge about coding or anything .is it safe to enter into this course ?",
#                         "authorDisplayName": "BI OS",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu-kbHb7zF3F4-xjC089GmZxmhYt_JB01c1R5UhXdg=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCu4JRmFqv_2AzukEk6uimow",
#                         "authorChannelId": {
#                             "value": "UCu4JRmFqv_2AzukEk6uimow"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 0,
#                         "publishedAt": "2022-05-16T03:44:30Z",
#                         "updatedAt": "2022-05-16T03:44:30Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "aQEOeCEFgERFp9urRJfopFw3txk",
#             "id": "Ugw6QqtwzPIijxDusqZ4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "Ix4VdINGGnWoT5NYLIzxQ8EU4KQ",
#                     "id": "Ugw6QqtwzPIijxDusqZ4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "Analyze given data and give insights... Sounds common sense to me... But it&#39;s now called as data science... \ud83d\ude01",
#                         "textOriginal": "Analyze given data and give insights... Sounds common sense to me... But it's now called as data science... \ud83d\ude01",
#                         "authorDisplayName": "Shazia Asif",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu9xUpwpPJdZuctAnguGDsiEs_ayinepp5-7FqiVJg=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UC-BAATQDfHr5h4JmJUxBNBg",
#                         "authorChannelId": {
#                             "value": "UC-BAATQDfHr5h4JmJUxBNBg"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-05-12T07:27:24Z",
#                         "updatedAt": "2022-05-12T07:27:24Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "CIoj0Dw8eneumZHOzOpCIt__ow8",
#             "id": "Ugx1sf0jKLTPVLaYU5Z4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "FSys-emnKhdXJvBcPAUDd-Pbyr0",
#                     "id": "Ugx1sf0jKLTPVLaYU5Z4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "I have completed b. Sc with maths am I eligible to do master in data science",
#                         "textOriginal": "I have completed b. Sc with maths am I eligible to do master in data science",
#                         "authorDisplayName": "Reetu Guliasatsany",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu8k5YTBlhGsDdYMKw3qMT4vxRoqC-iah1ArAg=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UC5PEck7ld2_Oh-cdjXNtvEg",
#                         "authorChannelId": {
#                             "value": "UC5PEck7ld2_Oh-cdjXNtvEg"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-04-10T09:00:59Z",
#                         "updatedAt": "2022-04-10T09:00:59Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "hN7vo7puwTjsKUxQM8xIbVteM7c",
#             "id": "UgxIWKJ_iu1hvuSeAB14AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "EqRoqbNAJgjKTJnyBm6KpRB-Oh8",
#                     "id": "UgxIWKJ_iu1hvuSeAB14AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "Excellent video,  kudos to the creators... where can i persue and get certified?",
#                         "textOriginal": "Excellent video,  kudos to the creators... where can i persue and get certified?",
#                         "authorDisplayName": "Guganthan Andiappan",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu94O4VidYr_x5khVFTTc5uOIKHwBXVPyDtTPQ=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCTLt9bF3ipmgCBL99KExTAQ",
#                         "authorChannelId": {
#                             "value": "UCTLt9bF3ipmgCBL99KExTAQ"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-04-08T06:55:45Z",
#                         "updatedAt": "2022-04-08T06:55:45Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "8F46T8MC3gBaewFLayRbEoEdp3s",
#             "id": "UgxZPYRRMluP4tCkJm14AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "gVaq6j1Q_Kmyd_r16UUQrhfef5I",
#                     "id": "UgxZPYRRMluP4tCkJm14AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "t was a great overview of all the process",
#                         "textOriginal": "t was a great overview of all the process",
#                         "authorDisplayName": "Himanshu Sura",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu_wU3PWQAEV7kOVmfKSdpt1a5aYddoSLq_vS3tQ=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UC_EH6919xVArdW_WxeS4KZQ",
#                         "authorChannelId": {
#                             "value": "UC_EH6919xVArdW_WxeS4KZQ"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-04-05T06:29:14Z",
#                         "updatedAt": "2022-04-05T06:29:14Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "4YjYNqWF4IYkwq-CHUvJaAKVefM",
#             "id": "UgzqX_noJ7Ci0ZEoO1d4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "RZ9_gvQznv4s2t1qi5Ob9ZWj1B0",
#                     "id": "UgzqX_noJ7Ci0ZEoO1d4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "Finally a video that doesn&#39;t scare me to quit learning data science",
#                         "textOriginal": "Finally a video that doesn't scare me to quit learning data science",
#                         "authorDisplayName": "Rex",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu9lE4GC9o5QZf87vVRgXZXNo3nCNw6yn-wyFXLrtQ=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UC4vaw-Gk6AMB5xUW8LX-Ngg",
#                         "authorChannelId": {
#                             "value": "UC4vaw-Gk6AMB5xUW8LX-Ngg"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 0,
#                         "publishedAt": "2022-03-24T19:30:02Z",
#                         "updatedAt": "2022-03-24T19:30:02Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "8G6wSAxyJa5e_r7p05gznoxL0_U",
#             "id": "Ugw0Mc5DF8hoSKi-XUl4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "L25c9annCIkxYRURjJew1a68-I0",
#                     "id": "Ugw0Mc5DF8hoSKi-XUl4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "I feel like this is not good for beginners because there are so many technical terms I didn\u2019t get. Maybe break it down a bit",
#                         "textOriginal": "I feel like this is not good for beginners because there are so many technical terms I didn\u2019t get. Maybe break it down a bit",
#                         "authorDisplayName": "Rosebella Thompson",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu-nnsxWh-m9dzoDvwcM-BJRLRhvh20i89xU3w=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCnUCMzeYcyYoaGGmliRSwNw",
#                         "authorChannelId": {
#                             "value": "UCnUCMzeYcyYoaGGmliRSwNw"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-03-11T21:17:30Z",
#                         "updatedAt": "2022-03-11T21:17:30Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "bKfX6x0z7txJ-u976apDWZKTW6o",
#             "id": "UgxQ3NDft7Rg6xPbyyJ4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "j0KvZZhS1mQB7X8UIuWc6vx3hJ4",
#                     "id": "UgxQ3NDft7Rg6xPbyyJ4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "Haha Indians cant talk about anything without discussing money aspect",
#                         "textOriginal": "Haha Indians cant talk about anything without discussing money aspect",
#                         "authorDisplayName": "Manny Khan",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu90RVoKnB4ugYc4_rJjsFfud4doukY3IYdOWw=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCYvek4ZumpFPJFEbxU4IWeA",
#                         "authorChannelId": {
#                             "value": "UCYvek4ZumpFPJFEbxU4IWeA"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 0,
#                         "publishedAt": "2022-03-05T17:43:21Z",
#                         "updatedAt": "2022-03-05T17:43:37Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 0,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "NA9RYX1KK24CwDzdIID6AE3MmtA",
#             "id": "Ugxps5PrvFJJlZ7DqpV4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "XEoooJoO3ZC9W8NDkpuZSAWIh7g",
#                     "id": "Ugxps5PrvFJJlZ7DqpV4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "\ud83d\udc4f\ud83c\udffb\ud83d\udc4f\ud83c\udffb",
#                         "textOriginal": "\ud83d\udc4f\ud83c\udffb\ud83d\udc4f\ud83c\udffb",
#                         "authorDisplayName": "Brenda Martinez",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/osykcl4n4bCfxHRGzJhd4Bu-s033kFcOrTbfEDXoEa4h47oEcyecieI48Q74HnTIXqE5mEO2rA=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UChUj4KJLWz-7TWNqR69aSwQ",
#                         "authorChannelId": {
#                             "value": "UChUj4KJLWz-7TWNqR69aSwQ"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-03-05T09:13:54Z",
#                         "updatedAt": "2022-03-05T09:13:54Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 2,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "as8CqIMq9SBIIPkbC5pPrUgOO68",
#             "id": "UgzpXL1GqqMn2LGZVVZ4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "JW9O3OZAIthkBKyeoC1MTw3MtG0",
#                     "id": "UgzpXL1GqqMn2LGZVVZ4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "Your video is very valuable to understand the Data Science. Awesome.",
#                         "textOriginal": "Your video is very valuable to understand the Data Science. Awesome.",
#                         "authorDisplayName": "Mohammad Aamir Jahangir",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu_EPEPcRLCrmQoBILuQ7g1p1pLcue6_3gi9KEF_ag=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCpNtRb49OqIjMmLtpbSDdBA",
#                         "authorChannelId": {
#                             "value": "UCpNtRb49OqIjMmLtpbSDdBA"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-03-05T07:15:11Z",
#                         "updatedAt": "2022-03-05T07:15:11Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "jcXiLb0rSJ_54tgx_8Yzb_mZHQU",
#             "id": "UgyDf7VwACBV0Z2s7rB4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "OSMkN61adieV_t1le8mmf1Egkq4",
#                     "id": "UgyDf7VwACBV0Z2s7rB4AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "nicely explaing, intresting video",
#                         "textOriginal": "nicely explaing, intresting video",
#                         "authorDisplayName": "amit shah",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu8lj0BDhESJja0c7eBD71UsYxF5c6lUV-iRL8BVqw=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCyb-Sixhv3hNvVlnuGPgavQ",
#                         "authorChannelId": {
#                             "value": "UCyb-Sixhv3hNvVlnuGPgavQ"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-03-05T04:30:22Z",
#                         "updatedAt": "2022-03-05T04:30:22Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         },
#         {
#             "kind": "youtube#commentThread",
#             "etag": "-lFevRPoNPTts1DgUUXxjUafEgM",
#             "id": "UgxuYwMuphTp-scQds54AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "topLevelComment": {
#                     "kind": "youtube#comment",
#                     "etag": "obbqRMJN393V7Q8w557FWdUvkgU",
#                     "id": "UgxuYwMuphTp-scQds54AaABAg",
#                     "snippet": {
#                         "videoId": "X3paOmcrTjQ",
#                         "textDisplay": "You&#39;re telling what exactly is Data Science, and you&#39;re beginning the video by saying watch this video if you&#39;re passionate about data science. How can someone be passionate about DS if they don&#39;t have idea about DS? Make a video so that people can relate and feel DS is the field they want to get into, this is something which makes them happy,.. etc",
#                         "textOriginal": "You're telling what exactly is Data Science, and you're beginning the video by saying watch this video if you're passionate about data science. How can someone be passionate about DS if they don't have idea about DS? Make a video so that people can relate and feel DS is the field they want to get into, this is something which makes them happy,.. etc",
#                         "authorDisplayName": "rakshith vrishabhendra",
#                         "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu8sqUmjMVlzTAy1fHciDL_duTIgc2ukoUJseOIpDg=s48-c-k-c0x00ffffff-no-rj",
#                         "authorChannelUrl": "http://www.youtube.com/channel/UCE9f8wJI6hJJVhuDB2XqOhQ",
#                         "authorChannelId": {
#                             "value": "UCE9f8wJI6hJJVhuDB2XqOhQ"
#                         },
#                         "canRate": true,
#                         "viewerRating": "none",
#                         "likeCount": 1,
#                         "publishedAt": "2022-02-13T09:40:36Z",
#                         "updatedAt": "2022-02-13T09:40:36Z"
#                     }
#                 },
#                 "canReply": true,
#                 "totalReplyCount": 1,
#                 "isPublic": true
#             }
#         }
#     ]
# }

# %%
# query each item one by one from multiple json data
for vid in YTdf["id.videoId"][:1]:
    request = youtube.commentThreads().list(part="snippet", videoId=vid)
    response = request.execute()
    
    print(json.dumps(response["items"][1], indent=4))
    print("**************************************************")
    print(json.dumps(response["items"][2], indent=4))
    print("**************************************************")
    print(json.dumps(response["items"][3], indent=4))
# Out:
# {
#     "kind": "youtube#commentThread",
#     "etag": "16M5IlA8kSMbdXJ2JSJWvWvpBXI",
#     "id": "UgwIqSnkVJX2r5L8uTB4AaABAg",
#     "snippet": {
#         "videoId": "X3paOmcrTjQ",
#         "topLevelComment": {
#             "kind": "youtube#comment",
#             "etag": "a3h0AUB3Ywh2dFT-TsSsxCsnNWY",
#             "id": "UgwIqSnkVJX2r5L8uTB4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "textDisplay": "<b>This was NOT helpful at all! I have no idea what a Data Scientist is..and you assumed people like myself would know the terms you used or how it is applied in business scenarios. I came here to learn..but you created a video for people who already know the basics of data science and how it is applied..which means this was NOT a video for beginners. This doesn&#39;t make me want to watch any more of your videos since you did such a poor job here!</b> \u2639\ud83d\udc4e",
#                 "textOriginal": "*This was NOT helpful at all! I have no idea what a Data Scientist is..and you assumed people like myself would know the terms you used or how it is applied in business scenarios. I came here to learn..but you created a video for people who already know the basics of data science and how it is applied..which means this was NOT a video for beginners. This doesn't make me want to watch any more of your videos since you did such a poor job here!* \u2639\ud83d\udc4e",
#                 "authorDisplayName": "Nightbird",
#                 "authorProfileImageUrl": "https://yt3.ggpht.com/XbE-hPXHwWeYip09NgmngQO4W7bQ5sFTAnnRT-yNJl9EiBg4eJhpqJ8QjyyDi2yUsAzCLA4rjw=s48-c-k-c0x00ffffff-no-rj",
#                 "authorChannelUrl": "http://www.youtube.com/channel/UCkzrrYMaT5O9s-76qvKRDxg",
#                 "authorChannelId": {
#                     "value": "UCkzrrYMaT5O9s-76qvKRDxg"
#                 },
#                 "canRate": true,
#                 "viewerRating": "none",
#                 "likeCount": 1,
#                 "publishedAt": "2022-08-13T18:11:01Z",
#                 "updatedAt": "2022-08-13T18:11:01Z"
#             }
#         },
#         "canReply": true,
#         "totalReplyCount": 0,
#         "isPublic": true
#     }
# }
# **************************************************
# {
#     "kind": "youtube#commentThread",
#     "etag": "BUdITpJa7o75S1mXteNfhzv3Drg",
#     "id": "UgxDnm-NUVoFFqWV_jp4AaABAg",
#     "snippet": {
#         "videoId": "X3paOmcrTjQ",
#         "topLevelComment": {
#             "kind": "youtube#comment",
#             "etag": "iuaA7EsdS6SH8U-eZXIjeSWTCA0",
#             "id": "UgxDnm-NUVoFFqWV_jp4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "textDisplay": "I am thinking to take cse with data science in NSUT :)... btw thanks \ud83d\ude0a",
#                 "textOriginal": "I am thinking to take cse with data science in NSUT :)... btw thanks \ud83d\ude0a",
#                 "authorDisplayName": "Sayan Mondal",
#                 "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu_-B-kRmP5HtfqRFfie00NWMF7k-27BKOv0dXGwMg=s48-c-k-c0x00ffffff-no-rj",
#                 "authorChannelUrl": "http://www.youtube.com/channel/UCtkuXL-WSFKYuvpWLa49bsg",
#                 "authorChannelId": {
#                     "value": "UCtkuXL-WSFKYuvpWLa49bsg"
#                 },
#                 "canRate": true,
#                 "viewerRating": "none",
#                 "likeCount": 1,
#                 "publishedAt": "2022-08-11T18:25:04Z",
#                 "updatedAt": "2022-08-11T18:25:04Z"
#             }
#         },
#         "canReply": true,
#         "totalReplyCount": 1,
#         "isPublic": true
#     }
# }
# **************************************************
# {
#     "kind": "youtube#commentThread",
#     "etag": "uhpzFrbvgSaBHXyUKNSV5PlYz6U",
#     "id": "UgyJjviDA6gwuYiETod4AaABAg",
#     "snippet": {
#         "videoId": "X3paOmcrTjQ",
#         "topLevelComment": {
#             "kind": "youtube#comment",
#             "etag": "EwEQP0goC0ldMd84MqYKj1Y_R7I",
#             "id": "UgyJjviDA6gwuYiETod4AaABAg",
#             "snippet": {
#                 "videoId": "X3paOmcrTjQ",
#                 "textDisplay": "Is the salary monthly or annual?",
#                 "textOriginal": "Is the salary monthly or annual?",
#                 "authorDisplayName": "aryan puri",
#                 "authorProfileImageUrl": "https://yt3.ggpht.com/ytc/AMLnZu-Tr4vTTChhSrCoNKXdWupZpJK2wR7zuCGIsg=s48-c-k-c0x00ffffff-no-rj",
#                 "authorChannelUrl": "http://www.youtube.com/channel/UCHWEjQjQgPltdbTDVTO-qBA",
#                 "authorChannelId": {
#                     "value": "UCHWEjQjQgPltdbTDVTO-qBA"
#                 },
#                 "canRate": true,
#                 "viewerRating": "none",
#                 "likeCount": 0,
#                 "publishedAt": "2022-07-05T11:12:44Z",
#                 "updatedAt": "2022-07-05T11:12:44Z"
#             }
#         },
#         "canReply": true,
#         "totalReplyCount": 1,
#         "isPublic": true
#     }
# }

# %%
for vid in YTdf["id.videoId"][:1]:
    request = youtube.commentThreads().list(part="snippet", videoId=vid)
    response = request.execute()
    comments = response["items"]
    print(len(comments)) # the number of comments for videos (based on the number of videoID we got)
# Out:
# 20

# %%
# initialize the dictionary with lists
comments_info ={"video_id":[],"likeCount":[],"replyCount":[],"publishDate":[],"textOriginal":[],
                "authorDisplayName":[],"authorChannelId":[],"authorChannelUrl":[]}
#get data 
for vid in YTdf["id.videoId"][:1]:
    try:
        request = youtube.commentThreads().list(part="snippet", videoId=vid)
        response = request.execute()
        comments = response['items']
        
        for i in range(0, len(comments)):
            snippet = comments[i]['snippet']
            #...................................................#
            video_id = snippet['videoId']
            replyCount = snippet['totalReplyCount']
            #--------------------------------------------------#
            #--------------------------------------------------#
            top_snippet = snippet['topLevelComment']['snippet']
            #.................................................. #
            likeCount = top_snippet['likeCount']
            publishDate = top_snippet['publishedAt']
            textOriginal = top_snippet['textOriginal']
            authorDisplayName = top_snippet['authorDisplayName']
            authorChannelId = top_snippet['authorChannelId']['value']
            authorChannelUrl = top_snippet['authorChannelUrl']

            comments_info["video_id"].append(video_id)
            comments_info["likeCount"].append(likeCount)
            comments_info["replyCount"].append(replyCount)
            comments_info["publishDate"].append(publishDate)
            comments_info["textOriginal"].append(textOriginal)
            comments_info["authorDisplayName"].append(authorDisplayName)
            comments_info["authorChannelId"].append(authorChannelId)
            comments_info["authorChannelUrl"].append(authorChannelUrl)
            
            print(video_id, "success")
        
    except:
        print(video_id, "error occured")
        
        
    time.sleep(5)
# Out:
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success
# X3paOmcrTjQ success

# %%
YTcomments = pd.DataFrame(comments_info)
YTcomments.head()
# Out:
#       video_id  likeCount  replyCount           publishDate  \
# 0  X3paOmcrTjQ         43           4  2021-09-02T18:04:08Z
# 1  X3paOmcrTjQ          1           0  2022-08-13T18:11:01Z
# 2  X3paOmcrTjQ          1           1  2022-08-11T18:25:04Z
# 3  X3paOmcrTjQ          0           1  2022-07-05T11:12:44Z
# 4  X3paOmcrTjQ          1           1  2022-07-03T09:15:02Z
#
#                                         textOriginal  authorDisplayName  \
# 0  🔥Explore Our FREE Courses With Completion Cert...        Simplilearn
# 1  *This was NOT helpful at all! I have no idea w...          Nightbird
# 2  I am thinking to take cse with data science in...       Sayan Mondal
# 3                   Is the salary monthly or annual?         aryan puri
# 4            Captions, please. Thank you in advance!  Slow Down Cooking
#
#             authorChannelId                                   authorChannelUrl
# 0  UCsvqVGtbbyHaMoevxPAq9Fg  http://www.youtube.com/channel/UCsvqVGtbbyHaMo...
# 1  UCkzrrYMaT5O9s-76qvKRDxg  http://www.youtube.com/channel/UCkzrrYMaT5O9s-...
# 2  UCtkuXL-WSFKYuvpWLa49bsg  http://www.youtube.com/channel/UCtkuXL-WSFKYuv...
# 3  UCHWEjQjQgPltdbTDVTO-qBA  http://www.youtube.com/channel/UCHWEjQjQgPltdb...
# 4  UCFTFCadazGjRtJwh4neDsCg  http://www.youtube.com/channel/UCFTFCadazGjRtJ...

# %%
YTcomments.shape
# Out:
# (20, 8)

# %%
# Split the date
split_comment = YTcomments['publishDate'].astype(str).str.split("T")
YTcomments['PDate'] = split_comment.str[0]
YTcomments['PTime'] = split_comment.str[1] 
print(YTcomments['PDate'].head())
print(YTcomments['PTime'].head()) #Times are expressed in UTC (Coordinated Universal Time), with a special UTC designator ("Z").
# Out:
# 0    2021-09-02
# 1    2022-08-13
# 2    2022-08-11
# 3    2022-07-05
# 4    2022-07-03
# Name: PDate, dtype: object
# 0    18:04:08Z
# 1    18:11:01Z
# 2    18:25:04Z
# 3    11:12:44Z
# 4    09:15:02Z
# Name: PTime, dtype: object

# %%
YTcomments.to_csv("YTcomments_example.csv")

# %% [markdown]
# ## Action 1: Get all the comments for the 50 videos and store the data into pandas dataframe

# %% [markdown]
# ## Example 2: Scrape YouTube videos statistics

# %%
#get video stats using youtube.videos().list(part="statistics",id=vid)
# multiple nested json data
for vid in YTdf["id.videoId"][:2]:
    request2 = youtube.videos().list(part="statistics",id=vid)
    response2 = request2.execute()
    print(json.dumps(response2, indent=4))
# Out:
# {
#     "kind": "youtube#videoListResponse",
#     "etag": "GuG4RheTxXAS5Uv6gkdO0LTTnoE",
#     "items": [
#         {
#             "kind": "youtube#video",
#             "etag": "_5vqx5E-IlYIQKZZKVq83jnN5tA",
#             "id": "X3paOmcrTjQ",
#             "statistics": {
#                 "viewCount": "2974252",
#                 "likeCount": "44031",
#                 "favoriteCount": "0",
#                 "commentCount": "1087"
#             }
#         }
#     ],
#     "pageInfo": {
#         "totalResults": 1,
#         "resultsPerPage": 1
#     }
# }
# {
#     "kind": "youtube#videoListResponse",
#     "etag": "tJiUFS1AtpilByl7moiwY4LT33s",
#     "items": [
#         {
#             "kind": "youtube#video",
#             "etag": "ggZbkUF7VkgDbIetmlVqhvQe5Xk",
#             "id": "RBSUwFGa6Fk",
#             "statistics": {
#                 "viewCount": "30161",
#                 "likeCount": "1100",
#                 "favoriteCount": "0",
#                 "commentCount": "22"
#             }
#         }
#     ],
#     "pageInfo": {
#         "totalResults": 1,
#         "resultsPerPage": 1
#     }
# }

# %% [markdown]
# ## Action 2: Parse the video statistics (json data) and store them into pandas dataframe (for all the videos in the url)
#
# - get all the statistics of videos, including: videoID,viewCount, likeCount, favoriteCount, and CommentCount
