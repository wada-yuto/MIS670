# %% [markdown]
# # Social Media Analytics -- Twitter Scraping
#
# Get your Twitter API
#
# API: Application Program Interface
#
# API is a set of programming instructions and protocol for accessing the data available through online companies such as Twitter, Facebook, Youtube, Google, and many others (New York Times)
# it is called a software-to-software interface.

# %% [markdown]
# # Tweepy

# %% [markdown]
# **install the library**
#
# !pip install tweepy
#
# https://anaconda.org/conda-forge/tweepy

# %%
import tweepy
import pandas as pd

# %%
# put your credential API information here (do not share your API to the public)
# API Consumer Key and Secret from Twitter
api_key = "WsEUv6afCiNthkSLWHIHn8yUM"
api_secret = "jtg2kd1CFL1txDao6NouIUO7xZzCXSM4yiP4WyuiiqQ50qTtjf"

access_token = "1564294883636088838-jhUHzc9xuIH9WMu6wCPahsWM4LiwaG"
access_token_secret = "vM6EmVcxk3L94D1bVQz19MliIUcSW5uA9660IZk1FQken"

# authentication
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True)

# %% [markdown]
# ## Example 1: search tweets with specific keywords or usernames

# %%
for status in tweepy.Cursor(api.search_tweets,q="KStateBusiness",
                            until='2022-10-11', #Twitter will automatically sample the last 7 days of data, and only allows you to get 7-day data
                            result_type='recent',
                            include_entities=True,
                            tweet_mode='extended', #otherwise it only captures 140 characters
                            lang="en").items(5):
    print(type(status), status) #please do not print all of the contents to the lab assignment submission, this is just for an illustration in class
# Out:
# <class 'tweepy.models.Status'> Status(_api=<tweepy.api.API object at 0x7fc21a20e520>, _json={'created_at': 'Mon Oct 10 16:47:02 +0000 2022', 'id': 1579513851384852482, 'id_str': '1579513851384852482', 'full_text': "We can't wait to hear your ideas for new venture projects at K-State Launch! Learn more about this event, and get ready to share your plans! 👉 👉 https://t.co/Qd7D1p8O5a https://t.co/blIriQRPYu", 'truncated': False, 'display_text_range': [0, 168], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Qd7D1p8O5a', 'expanded_url': 'https://bit.ly/3SO7nJX', 'display_url': 'bit.ly/3SO7nJX', 'indices': [145, 168]}], 'media': [{'id': 1579513847605563393, 'id_str': '1579513847605563393', 'indices': [169, 192], 'media_url': 'http://pbs.twimg.com/media/FeuPecxXEAEk4VP.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FeuPecxXEAEk4VP.jpg', 'url': 'https://t.co/blIriQRPYu', 'display_url': 'pic.twitter.com/blIriQRPYu', 'expanded_url': 'https://twitter.com/KStateBusiness/status/1579513851384852482/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 533, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 940, 'resize': 'fit'}, 'large': {'w': 1204, 'h': 943, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1579513847605563393, 'id_str': '1579513847605563393', 'indices': [169, 192], 'media_url': 'http://pbs.twimg.com/media/FeuPecxXEAEk4VP.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FeuPecxXEAEk4VP.jpg', 'url': 'https://t.co/blIriQRPYu', 'display_url': 'pic.twitter.com/blIriQRPYu', 'expanded_url': 'https://twitter.com/KStateBusiness/status/1579513851384852482/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 533, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 940, 'resize': 'fit'}, 'large': {'w': 1204, 'h': 943, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 162129701, 'id_str': '162129701', 'name': 'K-State Business', 'screen_name': 'KStateBusiness', 'location': 'Manhattan, KS', 'description': 'The K-State College of Business Administration offers a dynamic curriculum guided by business executives throughout the country.', 'url': 'https://t.co/0FEZ1as4wo', 'entities': {'url': {'urls': [{'url': 'https://t.co/0FEZ1as4wo', 'expanded_url': 'http://www.cba.k-state.edu', 'display_url': 'cba.k-state.edu', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3185, 'friends_count': 456, 'listed_count': 49, 'created_at': 'Fri Jul 02 19:57:20 +0000 2010', 'favourites_count': 1425, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'DDDCCA', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/162129701/1558204818', 'profile_link_color': '512888', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '522888', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notificatio ...
# <class 'tweepy.models.Status'> Status(_api=<tweepy.api.API object at 0x7fc21a20e520>, _json={'created_at': 'Sat Oct 08 21:21:27 +0000 2022', 'id': 1578858135539789825, 'id_str': '1578858135539789825', 'full_text': 'RT @EPedersenKS: Love being a part of this board. Engaged, smart group not afraid to challenge and give positive input. @StartupCats @KStat…', 'truncated': False, 'display_text_range': [0, 140], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'EPedersenKS', 'name': 'Erik Pedersen', 'id': 1357848338, 'id_str': '1357848338', 'indices': [3, 15]}, {'screen_name': 'StartupCats', 'name': 'K-State Entrepreneurship', 'id': 281703940, 'id_str': '281703940', 'indices': [120, 132]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1577067632460632066, 'id_str': '1577067632460632066', 'name': 'Lucy', 'screen_name': 'Lucy68262661', 'location': 'Los Angeles ', 'description': "I'm so good at sleeping i can do it with my eyes closed!", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 31, 'listed_count': 0, 'created_at': 'Mon Oct 03 22:46:48 +0000 2022', 'favourites_count': 7, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 60, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1577113200738254848/JbO7-FHY_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1577113200738254848/JbO7-FHY_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1577067632460632066/1664848077', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Oct 08 00:24:03 +0000 2022', 'id': 1578541696794517504, 'id_str': '1578541696794517504', 'full_text': 'Love being a part of this board. Engaged, smart group not afraid to challenge and give positive input. @StartupCats @KStateIP @KStateBusiness @DanePedersen401 @DreilingHCI @CivicPlus @jacksonchad @ecomm_ks @networkkansas @MHKChamber @goventuredash https://t.co/du3NhbQEth', 'truncated': False, 'display_text_range': [0, 247], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'StartupCats', 'name': 'K-State Entrepreneurship', 'id': 281703940, 'id_str': '281703940', 'indices': [103, 115]}, {'screen_name': 'KStateIP', 'name': 'K-State Innovation Partners', 'id': 4114417885, 'id_str': '4114417885', 'indices': [116, 125]}, {'screen_name': 'KStateBusiness', 'name': 'K-State Business', 'id': 162129701, 'id_str': '162129701', 'indices': [126, 141]}, {'screen_name': 'DanePedersen401', 'name': 'Dane Pedersen™', 'id': 977313595, 'id_str': '977313595', 'indices': [142, 158]}, {'screen_name': 'DreilingHCI', 'name': 'Dave Dreiling', 'id': 35749111, 'id_str': '35749111', 'indices': [159, 171]}, {'screen_name': 'CivicPlus', 'name': 'CivicPlus', 'id': 23066511, 'id_str': '23066511', 'indices': [172, 182]}, {'screen_name': 'jacksonchad', 'name': 'Chad Jackson', 'id': 65668931, 'id_str': '65668931', 'indices': [183, 195]}, ...
# <class 'tweepy.models.Status'> Status(_api=<tweepy.api.API object at 0x7fc21a20e520>, _json={'created_at': 'Sat Oct 08 00:24:03 +0000 2022', 'id': 1578541696794517504, 'id_str': '1578541696794517504', 'full_text': 'Love being a part of this board. Engaged, smart group not afraid to challenge and give positive input. @StartupCats @KStateIP @KStateBusiness @DanePedersen401 @DreilingHCI @CivicPlus @jacksonchad @ecomm_ks @networkkansas @MHKChamber @goventuredash https://t.co/du3NhbQEth', 'truncated': False, 'display_text_range': [0, 247], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'StartupCats', 'name': 'K-State Entrepreneurship', 'id': 281703940, 'id_str': '281703940', 'indices': [103, 115]}, {'screen_name': 'KStateIP', 'name': 'K-State Innovation Partners', 'id': 4114417885, 'id_str': '4114417885', 'indices': [116, 125]}, {'screen_name': 'KStateBusiness', 'name': 'K-State Business', 'id': 162129701, 'id_str': '162129701', 'indices': [126, 141]}, {'screen_name': 'DanePedersen401', 'name': 'Dane Pedersen™', 'id': 977313595, 'id_str': '977313595', 'indices': [142, 158]}, {'screen_name': 'DreilingHCI', 'name': 'Dave Dreiling', 'id': 35749111, 'id_str': '35749111', 'indices': [159, 171]}, {'screen_name': 'CivicPlus', 'name': 'CivicPlus', 'id': 23066511, 'id_str': '23066511', 'indices': [172, 182]}, {'screen_name': 'jacksonchad', 'name': 'Chad Jackson', 'id': 65668931, 'id_str': '65668931', 'indices': [183, 195]}, {'screen_name': 'ecomm_ks', 'name': 'E-Community Partnership', 'id': 3293475202, 'id_str': '3293475202', 'indices': [196, 205]}, {'screen_name': 'networkkansas', 'name': 'NetWork Kansas', 'id': 110735173, 'id_str': '110735173', 'indices': [206, 220]}, {'screen_name': 'MHKChamber', 'name': 'Manhattan Area Chamber of Commerce - Manhattan, KS', 'id': 29013772, 'id_str': '29013772', 'indices': [221, 232]}, {'screen_name': 'goventuredash', 'name': 'VentureDash', 'id': 1234182303406067718, 'id_str': '1234182303406067718', 'indices': [233, 247]}], 'urls': [], 'media': [{'id': 1578541691480465408, 'id_str': '1578541691480465408', 'indices': [248, 271], 'media_url': 'http://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg', 'url': 'https://t.co/du3NhbQEth', 'display_url': 'pic.twitter.com/du3NhbQEth', 'expanded_url': 'https://twitter.com/EPedersenKS/status/1578541696794517504/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}, 'small': {'w': 510, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1578541691480465408, 'id_str': '1578541691480465408', 'indices': [248, 271], 'media_url': 'http://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg', 'url': 'https://t.co/du3NhbQEth', 'display_url': 'pic.twitter.com/du3NhbQEth', 'expanded_url': 'https://twitter.com/EPedersenKS/status/1578541696794517504/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}, 'small': {'w': 510, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1357848338, 'id_str': '1357848338', 'name': 'Erik Pedersen', 'screen_name': 'EPedersenKS', 'location': 'Andover, KS', 'description': 'President and COO of NetWork Kansas (KS Center for Entrepreneurship). Passions are entrepreneurship, sports, hunting and family.', 'url': 'https://t.co/XJntTVmCRP', 'entities': {'url': {'urls': [{'url': 'https://t.co/XJntTVmCRP', 'expanded_ur ...
# <class 'tweepy.models.Status'> Status(_api=<tweepy.api.API object at 0x7fc21a20e520>, _json={'created_at': 'Fri Oct 07 21:45:01 +0000 2022', 'id': 1578501677157490690, 'id_str': '1578501677157490690', 'full_text': 'RT @KSUBizDean: Are you a K-State student with an idea for a product or service?  If so, our Entrepreneurship program wants to hear you pit…', 'truncated': False, 'display_text_range': [0, 140], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'KSUBizDean', 'name': 'Kevin Gwinner', 'id': 3344349911, 'id_str': '3344349911', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 162129701, 'id_str': '162129701', 'name': 'K-State Business', 'screen_name': 'KStateBusiness', 'location': 'Manhattan, KS', 'description': 'The K-State College of Business Administration offers a dynamic curriculum guided by business executives throughout the country.', 'url': 'https://t.co/0FEZ1as4wo', 'entities': {'url': {'urls': [{'url': 'https://t.co/0FEZ1as4wo', 'expanded_url': 'http://www.cba.k-state.edu', 'display_url': 'cba.k-state.edu', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3185, 'friends_count': 456, 'listed_count': 49, 'created_at': 'Fri Jul 02 19:57:20 +0000 2010', 'favourites_count': 1425, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4267, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'DDDCCA', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/162129701/1558204818', 'profile_link_color': '512888', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '522888', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Oct 07 15:23:58 +0000 2022', 'id': 1578405781799673869, 'id_str': '1578405781799673869', 'full_text': 'Are you a K-State student with an idea for a product or service?  If so, our Entrepreneurship program wants to hear you pitch in K-State Launch.  All K-State majors invited.  Get your share of $10,000 in prize money. https://t.co/DS4YY1qU3m', 'truncated': False, 'display_text_range': [0, 240], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/DS4YY1qU3m', 'expanded_url': 'https://www.k-state.edu/today/announcement/?id=85141#.Y0BDvttxVm8.twitter', 'display_url': 'k-state.edu/today/announce…', 'indices': [217, 240]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3344349911, 'id_str': '3344349911', 'name': 'Kevin Gwinner', 'screen_name': 'KSUBizDean', 'location': '', 'description': 'Dean of the Kansa ...
# <class 'tweepy.models.Status'> Status(_api=<tweepy.api.API object at 0x7fc21a20e520>, _json={'created_at': 'Fri Oct 07 15:25:10 +0000 2022', 'id': 1578406085089689600, 'id_str': '1578406085089689600', 'full_text': 'RT @KStateBusiness: Make sure you head to our insta account tomorrow to follow Byron Sides, Oper. &amp; Supply Chain Mangt major &amp;  @kstatespor…', 'truncated': False, 'display_text_range': [0, 148], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'KStateBusiness', 'name': 'K-State Business', 'id': 162129701, 'id_str': '162129701', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3344349911, 'id_str': '3344349911', 'name': 'Kevin Gwinner', 'screen_name': 'KSUBizDean', 'location': '', 'description': 'Dean of the Kansas State University \nCollege of Business Administration\nKSU Social Media User Policy: https://t.co/yj2x1h0u9c', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/yj2x1h0u9c', 'expanded_url': 'http://k-state.edu/social', 'display_url': 'k-state.edu/social', 'indices': [102, 125]}]}}, 'protected': False, 'followers_count': 763, 'friends_count': 169, 'listed_count': 11, 'created_at': 'Wed Jun 24 17:42:06 +0000 2015', 'favourites_count': 889, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1465, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/613791642529722368/Nz8eQSjI_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/613791642529722368/Nz8eQSjI_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3344349911/1537374354', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Oct 07 14:36:43 +0000 2022', 'id': 1578393891178512385, 'id_str': '1578393891178512385', 'full_text': 'Make sure you head to our insta account tomorrow to follow Byron Sides, Oper. &amp; Supply Chain Mangt major &amp;  @kstatesports cheerleader, as he takes us behind the scenes at the @KStateFB game against Iowa State. #catsmeanbusiness #KState https://t.co/nbVWSTkCed', 'truncated': False, 'display_text_range': [0, 243], 'entities': {'hashtags': [{'text': 'catsmeanbusiness', 'indices': [218, 235]}, {'text': 'KState', 'indices': [236, 243]}], 'symbols': [], 'user_mentions': [{'screen_name': 'kstatesports', 'name': 'K-State Athletics', 'id': 45595835, 'id_str': '45595835', 'indices': [116, 129]}, {'screen_name': 'KStateFB', 'name': 'K-State Football', 'id': 115192654, 'id_str': '115192654', 'indices': [183, 192]}], 'urls': [], 'media': [{'id': 1578393670407036930, 'id_str': '1578393670407036930', 'indices': [244, 267], 'media_url': 'http://pbs.twimg.com/media/FeeUrjhWIAISoOy.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FeeUrjhWIAISoOy.jpg', 'url': 'https://t.co/nbVWSTkCed', 'display_url': 'pic.twitter.com/nbVWSTkCed', 'expanded_url': 'https://twitter.com/KStateBusiness ...

# %%
dir(status)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'display_text_range',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'full_text',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'metadata',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'retweets',
#  'source',
#  'source_url',
#  'truncated',
#  'user']

# %% [markdown]
# ``From the above status json data``:
#
# _json={'created_at': 'Fri Sep 23 20:03:09 +0000 2022', 'id': 1573402612644413497, 'id_str': '1573402612644413497', 'full_text': 'RT @KStateBusiness: Shout out to @kstatecareer for bringing outstanding opportunities to our business students! At the All-University Caree…', 'truncated': False, 'display_text_range': [0, 140],

# %%
for status in tweepy.Cursor(api.search_tweets,q="KStateBusiness",
                            until='2022-10-11', #Twitter will automatically sample the last 7 days of data, and only allows you to get 7-day data
                            result_type='recent',
                            include_entities=True,
                            tweet_mode='extended', #otherwise it only captures 140 characters
                            lang="en").items(5):
    
    post_time = status.created_at # tweets posting time
    tweet_id = status.id_str # gets the tweets thread ID
    tweet = status.full_text # gets the tweets texts

    print(post_time, tweet_id, tweet)
# Out:
# 2022-10-10 16:47:02+00:00 1579513851384852482 We can't wait to hear your ideas for new venture projects at K-State Launch! Learn more about this event, and get ready to share your plans! 👉 👉 https://t.co/Qd7D1p8O5a https://t.co/blIriQRPYu
# 2022-10-08 21:21:27+00:00 1578858135539789825 RT @EPedersenKS: Love being a part of this board. Engaged, smart group not afraid to challenge and give positive input. @StartupCats @KStat…
# 2022-10-08 00:24:03+00:00 1578541696794517504 Love being a part of this board. Engaged, smart group not afraid to challenge and give positive input. @StartupCats @KStateIP @KStateBusiness @DanePedersen401 @DreilingHCI @CivicPlus @jacksonchad @ecomm_ks @networkkansas @MHKChamber @goventuredash https://t.co/du3NhbQEth
# 2022-10-07 21:45:01+00:00 1578501677157490690 RT @KSUBizDean: Are you a K-State student with an idea for a product or service?  If so, our Entrepreneurship program wants to hear you pit…
# 2022-10-07 15:25:10+00:00 1578406085089689600 RT @KStateBusiness: Make sure you head to our insta account tomorrow to follow Byron Sides, Oper. &amp; Supply Chain Mangt major &amp;  @kstatespor…

# %% [markdown]
# ### Prettify the Twitter data then get more data

# %%
import json

# %%
for status in tweepy.Cursor(api.search_tweets,q="KStateBusiness",
                            until='2022-10-11', #Twitter will automatically sample the last 7 days of data, and only allows you to get 7-day data
                            result_type='recent',
                            include_entities=True,
                            tweet_mode='extended', #otherwise it only captures 140 characters
                            lang="en").items(5):
    
    data = status._json #only query the json data from status
    print(json.dumps(data, indent=4)) #please do not print all of the contents to the lab assignment submission, this is just for an illustration in class
# Out:
# {
#     "created_at": "Mon Oct 10 16:47:02 +0000 2022",
#     "id": 1579513851384852482,
#     "id_str": "1579513851384852482",
#     "full_text": "We can't wait to hear your ideas for new venture projects at K-State Launch! Learn more about this event, and get ready to share your plans! \ud83d\udc49 \ud83d\udc49 https://t.co/Qd7D1p8O5a https://t.co/blIriQRPYu",
#     "truncated": false,
#     "display_text_range": [
#         0,
#         168
#     ],
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [],
#         "urls": [
#             {
#                 "url": "https://t.co/Qd7D1p8O5a",
#                 "expanded_url": "https://bit.ly/3SO7nJX",
#                 "display_url": "bit.ly/3SO7nJX",
#                 "indices": [
#                     145,
#                     168
#                 ]
#             }
#         ],
#         "media": [
#             {
#                 "id": 1579513847605563393,
#                 "id_str": "1579513847605563393",
#                 "indices": [
#                     169,
#                     192
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/FeuPecxXEAEk4VP.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/FeuPecxXEAEk4VP.jpg",
#                 "url": "https://t.co/blIriQRPYu",
#                 "display_url": "pic.twitter.com/blIriQRPYu",
#                 "expanded_url": "https://twitter.com/KStateBusiness/status/1579513851384852482/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                     "thumb": {
#                         "w": 150,
#                         "h": 150,
#                         "resize": "crop"
#                     },
#                     "small": {
#                         "w": 680,
#                         "h": 533,
#                         "resize": "fit"
#                     },
#                     "medium": {
#                         "w": 1200,
#                         "h": 940,
#                         "resize": "fit"
#                     },
#                     "large": {
#                         "w": 1204,
#                         "h": 943,
#                         "resize": "fit"
#                     }
#                 }
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "id": 1579513847605563393,
#                 "id_str": "1579513847605563393",
#                 "indices": [
#                     169,
#                     192
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/FeuPecxXEAEk4VP.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/FeuPecxXEAEk4VP.jpg",
#                 "url": "https://t.co/blIriQRPYu",
#                 "display_url": "pic.twitter.com/blIriQRPYu",
#                 "expanded_url": "https://twitter.com/KStateBusiness/status/1579513851384852482/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                     "thumb": {
#                         "w": 150,
#                         "h": 150,
#                         "resize": "crop"
#                     },
#                     "small": {
#                         "w": 680,
#                         "h": 533,
#                         "resize": "fit"
#                     },
#                     "medium": {
#                         "w": 1200,
#                         "h": 940,
#                         "resize": "fit"
#                     },
#                     "large": {
#                         "w": 1204,
#                         "h": 943,
#                         "resize": "fit"
#                     }
#                 }
#             }
#         ]
#     },
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "source": "<a href=\"https://sproutsocial.com\" rel=\"nofollow\">Sprout Social</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 162129701,
#         "id_str": "162129701",
#         "name": "K-State Business",
#         "screen_name": "KStateBusiness",
#         "location": "Manhattan, KS",
#         "description": "The K-State College of Business Administration offers a dynamic curriculum guided by business executives throughout the country.",
#         "url": "https://t.co/0FEZ1as4wo",
#         "entities": {
#             "url": {
#                 "urls": [
#                     {
#                         "url": "https://t.co/0FEZ1as4wo",
#                         "expanded_url": "http://www.cba.k-state.edu",
#                         "display_url": "cba.k-state.edu",
#                         "indices": [
#                             0,
#                             23
#                         ]
#                     }
#                 ]
#             },
#             "description": {
#                 "urls": []
#             }
#         },
#         "protected": false,
#         "followers_count": 3185,
#         "friends_count": 456,
#         "listed_count": 49,
#         "created_at": "Fri Jul 02 19:57:20 +0000 2010",
#         "favourites_count": 1425,
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "verified": false,
#         "statuses_count": 4267,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "is_translation_enabled": false,
#         "profile_background_color": "DDDCCA",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/162129701/1558204818",
#         "profile_link_color": "512888",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "522888",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "has_extended_profile": false,
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": false,
#         "follow_request_sent": false,
#         "notifications": false,
#         "translator_type": "none",
#         "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 0,
#     "favorite_count": 3,
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "lang": "en"
# }
# {
#     "created_at": "Sat Oct 08 21:21:27 +0000 2022",
#     "id": 1578858135539789825,
#     "id_str": "1578858135539789825",
#     "full_text": "RT @EPedersenKS: Love being a part of this board. Engaged, smart group not afraid to challenge and give positive input. @StartupCats @KStat\u2026",
#     "truncated": false,
#     "display_text_range": [
#         0,
#         140
#     ],
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [
#             {
#                 "screen_name": "EPedersenKS",
#                 "name": "Erik Pedersen",
#                 "id": 1357848338,
#                 "id_str": "1357848338",
#                 "indices": [
#                     3,
#                     15
#                 ]
#             },
#             {
#                 "screen_name": "StartupCats",
#                 "name": "K-State Entrepreneurship",
#                 "id": 281703940,
#                 "id_str": "281703940",
#                 "indices": [
#                     120,
#                     132
#                 ]
#             }
#         ],
#         "urls": []
#     },
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 1577067632460632066,
#         "id_str": "1577067632460632066",
#         "name": "Lucy",
#         "screen_name": "Lucy68262661",
#         "location": "Los Angeles ",
#         "description": "I'm so good at sleeping i can do it with my eyes closed!",
#         "url": null,
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "protected": false,
#         "followers_count": 1,
#         "friends_count": 31,
#         "listed_count": 0,
#         "created_at": "Mon Oct 03 22:46:48 +0000 2022",
#         "favourites_count": 7,
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "verified": false,
#         "statuses_count": 60,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "is_translation_enabled": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1577113200738254848/JbO7-FHY_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1577113200738254848/JbO7-FHY_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1577067632460632066/1664848077",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "has_extended_profile": true,
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": false,
#         "follow_request_sent": false,
#         "notifications": false,
#         "translator_type": "none",
#         "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "retweeted_status": {
#         "created_at": "Sat Oct 08 00:24:03 +0000 2022",
#         "id": 1578541696794517504,
#         "id_str": "1578541696794517504",
#         "full_text": "Love being a part of this board. Engaged, smart group not afraid to challenge and give positive input. @StartupCats @KStateIP @KStateBusiness @DanePedersen401 @DreilingHCI @CivicPlus @jacksonchad @ecomm_ks @networkkansas @MHKChamber @goventuredash https://t.co/du3NhbQEth",
#         "truncated": false,
#         "display_text_range": [
#             0,
#             247
#         ],
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "StartupCats",
#                     "name": "K-State Entrepreneurship",
#                     "id": 281703940,
#                     "id_str": "281703940",
#                     "indices": [
#                         103,
#                         115
#                     ]
#                 },
#                 {
#                     "screen_name": "KStateIP",
#                     "name": "K-State Innovation Partners",
#                     "id": 4114417885,
#                     "id_str": "4114417885",
#                     "indices": [
#                         116,
#                         125
#                     ]
#                 },
#                 {
#                     "screen_name": "KStateBusiness",
#                     "name": "K-State Business",
#                     "id": 162129701,
#                     "id_str": "162129701",
#                     "indices": [
#                         126,
#                         141
#                     ]
#                 },
#                 {
#                     "screen_name": "DanePedersen401",
#                     "name": "Dane Pedersen\u2122",
#                     "id": 977313595,
#                     "id_str": "977313595",
#                     "indices": [
#                         142,
#                         158
#                     ]
#                 },
#                 {
#                     "screen_name": "DreilingHCI",
#                     "name": "Dave Dreiling",
#                     "id": 35749111,
#                     "id_str": "35749111",
#                     "indices": [
#                         159,
#                         171
#                     ]
#                 },
#                 {
#                     "screen_name": "CivicPlus",
#                     "name": "CivicPlus",
#                     "id": 23066511,
#                     "id_str": "23066511",
#                     "indices": [
#                         172,
#                         182
#                     ]
#                 },
#                 {
#                     "screen_name": "jacksonchad",
#                     "name": "Chad Jackson",
#                     "id": 65668931,
#                     "id_str": "65668931",
#                     "indices": [
#                         183,
#                         195
#                     ]
#                 },
#                 {
#                     "screen_name": "ecomm_ks",
#                     "name": "E-Community Partnership",
#                     "id": 3293475202,
#                     "id_str": "3293475202",
#                     "indices": [
#                         196,
#                         205
#                     ]
#                 },
#                 {
#                     "screen_name": "networkkansas",
#                     "name": "NetWork Kansas",
#                     "id": 110735173,
#                     "id_str": "110735173",
#                     "indices": [
#                         206,
#                         220
#                     ]
#                 },
#                 {
#                     "screen_name": "MHKChamber",
#                     "name": "Manhattan Area Chamber of Commerce - Manhattan, KS",
#                     "id": 29013772,
#                     "id_str": "29013772",
#                     "indices": [
#                         221,
#                         232
#                     ]
#                 },
#                 {
#                     "screen_name": "goventuredash",
#                     "name": "VentureDash",
#                     "id": 1234182303406067718,
#                     "id_str": "1234182303406067718",
#                     "indices": [
#                         233,
#                         247
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1578541691480465408,
#                     "id_str": "1578541691480465408",
#                     "indices": [
#                         248,
#                         271
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg",
#                     "url": "https://t.co/du3NhbQEth",
#                     "display_url": "pic.twitter.com/du3NhbQEth",
#                     "expanded_url": "https://twitter.com/EPedersenKS/status/1578541696794517504/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 1536,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 510,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 900,
#                             "h": 1200,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1578541691480465408,
#                     "id_str": "1578541691480465408",
#                     "indices": [
#                         248,
#                         271
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg",
#                     "url": "https://t.co/du3NhbQEth",
#                     "display_url": "pic.twitter.com/du3NhbQEth",
#                     "expanded_url": "https://twitter.com/EPedersenKS/status/1578541696794517504/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 1536,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 510,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 900,
#                             "h": 1200,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1357848338,
#             "id_str": "1357848338",
#             "name": "Erik Pedersen",
#             "screen_name": "EPedersenKS",
#             "location": "Andover, KS",
#             "description": "President and COO of NetWork Kansas (KS Center for Entrepreneurship). Passions are entrepreneurship, sports, hunting and family.",
#             "url": "https://t.co/XJntTVmCRP",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/XJntTVmCRP",
#                             "expanded_url": "http://www.networkkansas.com",
#                             "display_url": "networkkansas.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1486,
#             "friends_count": 1069,
#             "listed_count": 45,
#             "created_at": "Tue Apr 16 20:45:41 +0000 2013",
#             "favourites_count": 20420,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 9382,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1503019993037946884/xZwDPpIq_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1503019993037946884/xZwDPpIq_normal.jpg",
#             "profile_link_color": "0084B4",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 9,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     "is_quote_status": false,
#     "retweet_count": 1,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "en"
# }
# {
#     "created_at": "Sat Oct 08 00:24:03 +0000 2022",
#     "id": 1578541696794517504,
#     "id_str": "1578541696794517504",
#     "full_text": "Love being a part of this board. Engaged, smart group not afraid to challenge and give positive input. @StartupCats @KStateIP @KStateBusiness @DanePedersen401 @DreilingHCI @CivicPlus @jacksonchad @ecomm_ks @networkkansas @MHKChamber @goventuredash https://t.co/du3NhbQEth",
#     "truncated": false,
#     "display_text_range": [
#         0,
#         247
#     ],
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [
#             {
#                 "screen_name": "StartupCats",
#                 "name": "K-State Entrepreneurship",
#                 "id": 281703940,
#                 "id_str": "281703940",
#                 "indices": [
#                     103,
#                     115
#                 ]
#             },
#             {
#                 "screen_name": "KStateIP",
#                 "name": "K-State Innovation Partners",
#                 "id": 4114417885,
#                 "id_str": "4114417885",
#                 "indices": [
#                     116,
#                     125
#                 ]
#             },
#             {
#                 "screen_name": "KStateBusiness",
#                 "name": "K-State Business",
#                 "id": 162129701,
#                 "id_str": "162129701",
#                 "indices": [
#                     126,
#                     141
#                 ]
#             },
#             {
#                 "screen_name": "DanePedersen401",
#                 "name": "Dane Pedersen\u2122",
#                 "id": 977313595,
#                 "id_str": "977313595",
#                 "indices": [
#                     142,
#                     158
#                 ]
#             },
#             {
#                 "screen_name": "DreilingHCI",
#                 "name": "Dave Dreiling",
#                 "id": 35749111,
#                 "id_str": "35749111",
#                 "indices": [
#                     159,
#                     171
#                 ]
#             },
#             {
#                 "screen_name": "CivicPlus",
#                 "name": "CivicPlus",
#                 "id": 23066511,
#                 "id_str": "23066511",
#                 "indices": [
#                     172,
#                     182
#                 ]
#             },
#             {
#                 "screen_name": "jacksonchad",
#                 "name": "Chad Jackson",
#                 "id": 65668931,
#                 "id_str": "65668931",
#                 "indices": [
#                     183,
#                     195
#                 ]
#             },
#             {
#                 "screen_name": "ecomm_ks",
#                 "name": "E-Community Partnership",
#                 "id": 3293475202,
#                 "id_str": "3293475202",
#                 "indices": [
#                     196,
#                     205
#                 ]
#             },
#             {
#                 "screen_name": "networkkansas",
#                 "name": "NetWork Kansas",
#                 "id": 110735173,
#                 "id_str": "110735173",
#                 "indices": [
#                     206,
#                     220
#                 ]
#             },
#             {
#                 "screen_name": "MHKChamber",
#                 "name": "Manhattan Area Chamber of Commerce - Manhattan, KS",
#                 "id": 29013772,
#                 "id_str": "29013772",
#                 "indices": [
#                     221,
#                     232
#                 ]
#             },
#             {
#                 "screen_name": "goventuredash",
#                 "name": "VentureDash",
#                 "id": 1234182303406067718,
#                 "id_str": "1234182303406067718",
#                 "indices": [
#                     233,
#                     247
#                 ]
#             }
#         ],
#         "urls": [],
#         "media": [
#             {
#                 "id": 1578541691480465408,
#                 "id_str": "1578541691480465408",
#                 "indices": [
#                     248,
#                     271
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg",
#                 "url": "https://t.co/du3NhbQEth",
#                 "display_url": "pic.twitter.com/du3NhbQEth",
#                 "expanded_url": "https://twitter.com/EPedersenKS/status/1578541696794517504/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                     "thumb": {
#                         "w": 150,
#                         "h": 150,
#                         "resize": "crop"
#                     },
#                     "large": {
#                         "w": 1536,
#                         "h": 2048,
#                         "resize": "fit"
#                     },
#                     "small": {
#                         "w": 510,
#                         "h": 680,
#                         "resize": "fit"
#                     },
#                     "medium": {
#                         "w": 900,
#                         "h": 1200,
#                         "resize": "fit"
#                     }
#                 }
#             }
#         ]
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "id": 1578541691480465408,
#                 "id_str": "1578541691480465408",
#                 "indices": [
#                     248,
#                     271
#                 ],
#                 "media_url": "http://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg",
#                 "media_url_https": "https://pbs.twimg.com/media/FegbTg_WYAABeNG.jpg",
#                 "url": "https://t.co/du3NhbQEth",
#                 "display_url": "pic.twitter.com/du3NhbQEth",
#                 "expanded_url": "https://twitter.com/EPedersenKS/status/1578541696794517504/photo/1",
#                 "type": "photo",
#                 "sizes": {
#                     "thumb": {
#                         "w": 150,
#                         "h": 150,
#                         "resize": "crop"
#                     },
#                     "large": {
#                         "w": 1536,
#                         "h": 2048,
#                         "resize": "fit"
#                     },
#                     "small": {
#                         "w": 510,
#                         "h": 680,
#                         "resize": "fit"
#                     },
#                     "medium": {
#                         "w": 900,
#                         "h": 1200,
#                         "resize": "fit"
#                     }
#                 }
#             }
#         ]
#     },
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 1357848338,
#         "id_str": "1357848338",
#         "name": "Erik Pedersen",
#         "screen_name": "EPedersenKS",
#         "location": "Andover, KS",
#         "description": "President and COO of NetWork Kansas (KS Center for Entrepreneurship). Passions are entrepreneurship, sports, hunting and family.",
#         "url": "https://t.co/XJntTVmCRP",
#         "entities": {
#             "url": {
#                 "urls": [
#                     {
#                         "url": "https://t.co/XJntTVmCRP",
#                         "expanded_url": "http://www.networkkansas.com",
#                         "display_url": "networkkansas.com",
#                         "indices": [
#                             0,
#                             23
#                         ]
#                     }
#                 ]
#             },
#             "description": {
#                 "urls": []
#             }
#         },
#         "protected": false,
#         "followers_count": 1486,
#         "friends_count": 1069,
#         "listed_count": 45,
#         "created_at": "Tue Apr 16 20:45:41 +0000 2013",
#         "favourites_count": 20420,
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "verified": false,
#         "statuses_count": 9382,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "is_translation_enabled": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1503019993037946884/xZwDPpIq_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1503019993037946884/xZwDPpIq_normal.jpg",
#         "profile_link_color": "0084B4",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "has_extended_profile": true,
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": false,
#         "follow_request_sent": false,
#         "notifications": false,
#         "translator_type": "none",
#         "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 1,
#     "favorite_count": 9,
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "lang": "en"
# }
# {
#     "created_at": "Fri Oct 07 21:45:01 +0000 2022",
#     "id": 1578501677157490690,
#     "id_str": "1578501677157490690",
#     "full_text": "RT @KSUBizDean: Are you a K-State student with an idea for a product or service?  If so, our Entrepreneurship program wants to hear you pit\u2026",
#     "truncated": false,
#     "display_text_range": [
#         0,
#         140
#     ],
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [
#             {
#                 "screen_name": "KSUBizDean",
#                 "name": "Kevin Gwinner",
#                 "id": 3344349911,
#                 "id_str": "3344349911",
#                 "indices": [
#                     3,
#                     14
#                 ]
#             }
#         ],
#         "urls": []
#     },
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 162129701,
#         "id_str": "162129701",
#         "name": "K-State Business",
#         "screen_name": "KStateBusiness",
#         "location": "Manhattan, KS",
#         "description": "The K-State College of Business Administration offers a dynamic curriculum guided by business executives throughout the country.",
#         "url": "https://t.co/0FEZ1as4wo",
#         "entities": {
#             "url": {
#                 "urls": [
#                     {
#                         "url": "https://t.co/0FEZ1as4wo",
#                         "expanded_url": "http://www.cba.k-state.edu",
#                         "display_url": "cba.k-state.edu",
#                         "indices": [
#                             0,
#                             23
#                         ]
#                     }
#                 ]
#             },
#             "description": {
#                 "urls": []
#             }
#         },
#         "protected": false,
#         "followers_count": 3185,
#         "friends_count": 456,
#         "listed_count": 49,
#         "created_at": "Fri Jul 02 19:57:20 +0000 2010",
#         "favourites_count": 1425,
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "verified": false,
#         "statuses_count": 4267,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "is_translation_enabled": false,
#         "profile_background_color": "DDDCCA",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/162129701/1558204818",
#         "profile_link_color": "512888",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "522888",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "has_extended_profile": false,
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": false,
#         "follow_request_sent": false,
#         "notifications": false,
#         "translator_type": "none",
#         "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "retweeted_status": {
#         "created_at": "Fri Oct 07 15:23:58 +0000 2022",
#         "id": 1578405781799673869,
#         "id_str": "1578405781799673869",
#         "full_text": "Are you a K-State student with an idea for a product or service?  If so, our Entrepreneurship program wants to hear you pitch in K-State Launch.  All K-State majors invited.  Get your share of $10,000 in prize money. https://t.co/DS4YY1qU3m",
#         "truncated": false,
#         "display_text_range": [
#             0,
#             240
#         ],
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/DS4YY1qU3m",
#                     "expanded_url": "https://www.k-state.edu/today/announcement/?id=85141#.Y0BDvttxVm8.twitter",
#                     "display_url": "k-state.edu/today/announce\u2026",
#                     "indices": [
#                         217,
#                         240
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 3344349911,
#             "id_str": "3344349911",
#             "name": "Kevin Gwinner",
#             "screen_name": "KSUBizDean",
#             "location": "",
#             "description": "Dean of the Kansas State University \nCollege of Business Administration\nKSU Social Media User Policy: https://t.co/yj2x1h0u9c",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/yj2x1h0u9c",
#                             "expanded_url": "http://k-state.edu/social",
#                             "display_url": "k-state.edu/social",
#                             "indices": [
#                                 102,
#                                 125
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 763,
#             "friends_count": 169,
#             "listed_count": 11,
#             "created_at": "Wed Jun 24 17:42:06 +0000 2015",
#             "favourites_count": 889,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 1465,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/613791642529722368/Nz8eQSjI_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/613791642529722368/Nz8eQSjI_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3344349911/1537374354",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 2,
#         "favorite_count": 5,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     "is_quote_status": false,
#     "retweet_count": 2,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "lang": "en"
# }
# {
#     "created_at": "Fri Oct 07 15:25:10 +0000 2022",
#     "id": 1578406085089689600,
#     "id_str": "1578406085089689600",
#     "full_text": "RT @KStateBusiness: Make sure you head to our insta account tomorrow to follow Byron Sides, Oper. &amp; Supply Chain Mangt major &amp;  @kstatespor\u2026",
#     "truncated": false,
#     "display_text_range": [
#         0,
#         148
#     ],
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [
#             {
#                 "screen_name": "KStateBusiness",
#                 "name": "K-State Business",
#                 "id": 162129701,
#                 "id_str": "162129701",
#                 "indices": [
#                     3,
#                     18
#                 ]
#             }
#         ],
#         "urls": []
#     },
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 3344349911,
#         "id_str": "3344349911",
#         "name": "Kevin Gwinner",
#         "screen_name": "KSUBizDean",
#         "location": "",
#         "description": "Dean of the Kansas State University \nCollege of Business Administration\nKSU Social Media User Policy: https://t.co/yj2x1h0u9c",
#         "url": null,
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "url": "https://t.co/yj2x1h0u9c",
#                         "expanded_url": "http://k-state.edu/social",
#                         "display_url": "k-state.edu/social",
#                         "indices": [
#                             102,
#                             125
#                         ]
#                     }
#                 ]
#             }
#         },
#         "protected": false,
#         "followers_count": 763,
#         "friends_count": 169,
#         "listed_count": 11,
#         "created_at": "Wed Jun 24 17:42:06 +0000 2015",
#         "favourites_count": 889,
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "verified": false,
#         "statuses_count": 1465,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "is_translation_enabled": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/613791642529722368/Nz8eQSjI_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/613791642529722368/Nz8eQSjI_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/3344349911/1537374354",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "has_extended_profile": false,
#         "default_profile": true,
#         "default_profile_image": false,
#         "following": false,
#         "follow_request_sent": false,
#         "notifications": false,
#         "translator_type": "none",
#         "withheld_in_countries": []
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "retweeted_status": {
#         "created_at": "Fri Oct 07 14:36:43 +0000 2022",
#         "id": 1578393891178512385,
#         "id_str": "1578393891178512385",
#         "full_text": "Make sure you head to our insta account tomorrow to follow Byron Sides, Oper. &amp; Supply Chain Mangt major &amp;  @kstatesports cheerleader, as he takes us behind the scenes at the @KStateFB game against Iowa State. #catsmeanbusiness #KState https://t.co/nbVWSTkCed",
#         "truncated": false,
#         "display_text_range": [
#             0,
#             243
#         ],
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "catsmeanbusiness",
#                     "indices": [
#                         218,
#                         235
#                     ]
#                 },
#                 {
#                     "text": "KState",
#                     "indices": [
#                         236,
#                         243
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "kstatesports",
#                     "name": "K-State Athletics",
#                     "id": 45595835,
#                     "id_str": "45595835",
#                     "indices": [
#                         116,
#                         129
#                     ]
#                 },
#                 {
#                     "screen_name": "KStateFB",
#                     "name": "K-State Football",
#                     "id": 115192654,
#                     "id_str": "115192654",
#                     "indices": [
#                         183,
#                         192
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1578393670407036930,
#                     "id_str": "1578393670407036930",
#                     "indices": [
#                         244,
#                         267
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FeeUrjhWIAISoOy.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FeeUrjhWIAISoOy.jpg",
#                     "url": "https://t.co/nbVWSTkCed",
#                     "display_url": "pic.twitter.com/nbVWSTkCed",
#                     "expanded_url": "https://twitter.com/KStateBusiness/status/1578393891178512385/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 510,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1536,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 900,
#                             "h": 1200,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1578393670407036930,
#                     "id_str": "1578393670407036930",
#                     "indices": [
#                         244,
#                         267
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FeeUrjhWIAISoOy.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FeeUrjhWIAISoOy.jpg",
#                     "url": "https://t.co/nbVWSTkCed",
#                     "display_url": "pic.twitter.com/nbVWSTkCed",
#                     "expanded_url": "https://twitter.com/KStateBusiness/status/1578393891178512385/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 510,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1536,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 900,
#                             "h": 1200,
#                             "resize": "fit"
#                         }
#                     }
#                 },
#                 {
#                     "id": 1578393670386065409,
#                     "id_str": "1578393670386065409",
#                     "indices": [
#                         244,
#                         267
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FeeUrjcWIAEX_om.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FeeUrjcWIAEX_om.jpg",
#                     "url": "https://t.co/nbVWSTkCed",
#                     "display_url": "pic.twitter.com/nbVWSTkCed",
#                     "expanded_url": "https://twitter.com/KStateBusiness/status/1578393891178512385/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 680,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1440,
#                             "h": 1440,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 162129701,
#             "id_str": "162129701",
#             "name": "K-State Business",
#             "screen_name": "KStateBusiness",
#             "location": "Manhattan, KS",
#             "description": "The K-State College of Business Administration offers a dynamic curriculum guided by business executives throughout the country.",
#             "url": "https://t.co/0FEZ1as4wo",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/0FEZ1as4wo",
#                             "expanded_url": "http://www.cba.k-state.edu",
#                             "display_url": "cba.k-state.edu",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 3185,
#             "friends_count": 456,
#             "listed_count": 49,
#             "created_at": "Fri Jul 02 19:57:20 +0000 2010",
#             "favourites_count": 1425,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 4267,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "DDDCCA",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/878271164715421696/KALME8st_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/162129701/1558204818",
#             "profile_link_color": "512888",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "522888",
#             "profile_text_color": "000000",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 2,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     "is_quote_status": false,
#     "retweet_count": 1,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "en"
# }

# %% [markdown]
# ### Store the json data into a list

# %%
# Get entire JSON File and store in a list called tweets_data[]
# create an empty list to store our tweets in
tweets_data = []

for status in tweepy.Cursor(api.search_tweets,q="KStateBusiness",
                            until='2022-10-11', #Twitter will automatically sample the last 7 days of data, and only allows you to get 7-day data
                            result_type='recent',
                            include_entities=True,
                            tweet_mode='extended', #otherwise it only captures 140 characters
                            lang="en").items(5):
    
    data = status._json #only query the json data from status
    json_clean = json.dumps(data, indent=4) #convert the dictionary to string #formatted json data
    tweets_data.append(json.loads(json_clean)) # store the json data into list tweets_data[]
    
# lets see how many we got
print(len(tweets_data))
# Out:
# 5

# %% [markdown]
# ### Store the list into a pandas dataframe

# %%
alltweets = pd.DataFrame(tweets_data)
alltweets
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Oct 10 16:47:02 +0000 2022  1579513851384852482  1579513851384852482
# 1  Sat Oct 08 21:21:27 +0000 2022  1578858135539789825  1578858135539789825
# 2  Sat Oct 08 00:24:03 +0000 2022  1578541696794517504  1578541696794517504
# 3  Fri Oct 07 21:45:01 +0000 2022  1578501677157490690  1578501677157490690
# 4  Fri Oct 07 15:25:10 +0000 2022  1578406085089689600  1578406085089689600
#
#                                            full_text  truncated  \
# 0  We can't wait to hear your ideas for new ventu...      False
# 1  RT @EPedersenKS: Love being a part of this boa...      False
# 2  Love being a part of this board. Engaged, smar...      False
# 3  RT @KSUBizDean: Are you a K-State student with...      False
# 4  RT @KStateBusiness: Make sure you head to our ...      False
#
#   display_text_range                                           entities  \
# 0           [0, 168]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           [0, 247]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 148]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 1579513847605563393, 'id_str...
# 1                                                NaN
# 2  {'media': [{'id': 1578541691480465408, 'id_str...
# 3                                                NaN
# 4                                                NaN
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  ... place contributors  \
# 0  <a href="https://sproutsocial.com" rel="nofoll...  ...  None         None
# 1  <a href="https://mobile.twitter.com" rel="nofo...  ...  None         None
# 2  <a href="http://twitter.com/download/iphone" r...  ...  None         None
# 3  <a href="http://twitter.com/download/iphone" r...  ...  None         None
# 4  <a href="https://mobile.twitter.com" rel="nofo...  ...  None         None
#
#   is_quote_status retweet_count favorite_count favorited retweeted  \
# 0           False             0              3     False     False
# 1           False             1              0     False     False
# 2           False             1              9     False     False
# 3           False             2              0     False     False
# 4           False             1              0     False     False
#
#   possibly_sensitive lang                                   retweeted_status
# 0              False   en                                                NaN
# 1                NaN   en  {'created_at': 'Sat Oct 08 00:24:03 +0000 2022...
# 2              False   en                                                NaN
# 3              False   en  {'created_at': 'Fri Oct 07 15:23:58 +0000 2022...
# 4                NaN   en  {'created_at': 'Fri Oct 07 14:36:43 +0000 2022...
#
# [5 rows x 28 columns]

# %%
#display the full texts
pd.options.display.max_colwidth = 500

# %%
alltweets.to_csv("allsample1.csv", index=False)

# %% [markdown]
# ### Find more data

# %%
for status in tweepy.Cursor(api.search_tweets,q="KStateBusiness",
                            until='2022-09-27', #Twitter will automatically sample the last 7 days of data, and only allows you to get 7-day data
                            result_type='recent',
                            include_entities=True,
                            tweet_mode='extended', #otherwise it only captures 140 characters
                            lang="en").items(5):
    
    userID = status.user.id_str
    userName = status.user.name
    screenName = status.user.screen_name
    userLocation = status.user.location
    user_descrip = status.user.description
    user_url = status.user.url
    followers = status.user.followers_count
    friends = status.user.friends_count
    user_ctime = status.user.created_at #user's account creating time
    source = status.source #iPhone or Android or Web

    print(userID, userName,screenName,userLocation,user_descrip,user_url,followers, friends, user_ctime, source)

# %% [markdown]
# ### Put them together and store the data into Pandas dataframe (Full scraper for Twitter search)

# %%
tweets = [] #initialize an empty list

for status in tweepy.Cursor(api.search_tweets,q="KStateBusiness",
                            until='2022-09-27', #Twitter will automatically sample the last 7 days of data, and only allows you to get 7-day data
                            result_type='recent',
                            include_entities=True,
                            tweet_mode='extended', #otherwise it only captures 140 characters
                            lang="en").items(5):
    
    post_time = status.created_at # tweets posting time
    tweet_id = status.id_str # gets the tweets thread ID
    tweet = status.full_text # gets the tweets texts
    userID = status.user.id_str
    userName = status.user.name
    screenName = status.user.screen_name
    userLocation = status.user.location
    user_descrip = status.user.description
    user_url = status.user.url
    followers = status.user.followers_count
    friends = status.user.friends_count
    user_ctime = status.user.created_at #user's account creating time
    source = status.source #iPhone or Android
    
    tweets.append((userName, screenName, userID, userLocation, user_descrip, user_url, followers, friends, user_ctime, source, 
                   post_time, tweet_id, tweet))

headers = ['userName', 'screenName', 'userID', 'userLocation', 'user_descrip', 'user_url', 'followers', 'friends', 'user_ctime',
           'source', 'post_time', 'tweet_id', 'tweet_text']

tweet_sample = pd.DataFrame(tweets,columns = headers)
tweet_sample.head()
# Out:
# Empty DataFrame
# Columns: [userName, screenName, userID, userLocation, user_descrip, user_url, followers, friends, user_ctime, source, post_time, tweet_id, tweet_text]
# Index: []

# %%
tweet_sample.to_csv("tweetsample.csv")

# %% [markdown]
# ### Action 1: Collect Tweets (at least 200 tweets) from any Topic interesting to you using the example, and store it into pandas dataframe.
#
# 1. only show the first five rows (using .head())
# 2. add two new data/variables besides the example includes, such as verification info ('verified'), the number of retweets ('retweet_count')

# %%
tweets_data = []

for status in tweepy.Cursor(api.search_tweets,q="Marathon",
                            until='2022-10-11', #Twitter will automatically sample the last 7 days of data, and only allows you to get 7-day data
                            result_type='recent',
                            include_entities=True,
                            tweet_mode='extended', #otherwise it only captures 140 characters
                            lang="en").items(200):
    
    data = status._json #only query the json data from status
    json_clean = json.dumps(data, indent=4) #convert the dictionary to string #formatted json data
    tweets_data.append(json.loads(json_clean)) # store the json data into list tweets_data[]
    
# lets see how many we got
print(len(tweets_data))

# %%
alltweets = pd.DataFrame(tweets_data)
alltweets

# %% [markdown]
# ## Example 2: get tweets from a specific user's page

# %%
# Get data from your own Twitter page (from timeline)
for myself in tweepy.Cursor(api.home_timeline).items(10):
    print(myself) #please do not print all of the contents to the lab assignment submission, this is just for an illustration in class
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-15-dd7e5f9a9c0e> in <module>
#       1 # Get data from your own Twitter page (from timeline)
# ----> 2 for myself in tweepy.Cursor(api.home_timeline).items(10):
#       3     print(myself) #please do not print all of the contents to the lab assignment submission, this is just for an illustration in class
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/api.py in home_timeline(self, **kwargs)
#     486         https://developer.twitter.com/en/docs/twitter-api/v1/tweets/timelines/api-reference/get-statuses-home_timeline
#     487         """
# --> 488         return self.request(
#     489             'GET', 'statuses/home_timeline', endpoint_parameters=(
#     490                 'count', 'since_id', 'max_id', 'trim_user', 'exclude_replies',
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     257                 raise Unauthorized(resp)
#     258             if resp.status_code == 403:
# --> 259                 raise Forbidden(resp)
#     260             if resp.status_code == 404:
#     261                 raise NotFound(resp)
#
# Forbidden: 403 Forbidden
# 453 - You currently have Essential access which includes access to Twitter API v2 endpoints only. If you need access to this endpoint, you’ll need to apply for Elevated access via the Developer Portal. You can learn more here: https://developer.twitter.com/en/docs/twitter-api/getting-started/about-twitter-api#v2-access-leve

# %%
# Get data from the friends (the users we are following)
friends = []
for friend in tweepy.Cursor(api.get_friends).items(): #https://github.com/tweepy/tweepy/releases/tag/v4.0.0
    jdata = friend._json 
    cleanj = json.dumps(jdata, indent=4) 
    friends.append(json.loads(cleanj)) 
    
fridf = pd.DataFrame(friends)
fridf.head()

# %% [markdown]
# ## Action 2: get data from your friends to Pandas Dataframe (at least 20 tweets)
#
# 1. get at least 20 variables (columns), such as tweets text ('text'), url, followers_count

# %%
# Get data from other users' pages
KSBS = []

Kstate_B = api.user_timeline(screen_name='KStateBusiness', #https://twitter.com/KStateBusiness
                           count=100, # 200 is the maximum allowed count
                           tweet_mode = 'extended'
                             # Necessary to keep full_text, otherwise only the first 140 words are extracted
                           )

for KSBS_tweet in Kstate_B[:5]: #extracting 5 latest tweets
    jKSBS = KSBS_tweet._json 
    cleanj_KSBS = json.dumps(jKSBS, indent=4) 
    KSBS.append(json.loads(cleanj_KSBS)) 
    
KSBSdf = pd.DataFrame(KSBS)
KSBSdf.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Sep 25 04:19:50 +0000 2022  1573889994099499009  1573889994099499009
# 1  Fri Sep 23 17:06:36 +0000 2022  1573358179580350464  1573358179580350464
# 2  Thu Sep 22 15:01:30 +0000 2022  1572964310808203266  1572964310808203266
# 3  Wed Sep 21 12:16:23 +0000 2022  1572560371541766152  1572560371541766152
# 4  Tue Sep 20 21:25:09 +0000 2022  1572336083928752134  1572336083928752134
#
#                                            full_text  truncated  \
# 0  #catsmeanbusiness @MartinezTheQB https://t.co/...      False
# 1  Shout out to @kstatecareer for bringing outsta...      False
# 2  Congratulations and welcome to our 2022-23 Men...      False
# 3  RT @KSUBizDean: Celebrating 53 College of Busi...      False
# 4  September is a busy month of networking, and m...      False
#
#   display_text_range                                           entities  \
# 0            [0, 32]  {'hashtags': [{'text': 'catsmeanbusiness', 'in...
# 1           [0, 231]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2            [0, 94]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 284]  {'hashtags': [{'text': 'catsmeanbusiness', 'in...
#
#                                               source in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                  None
# 1  <a href="https://mobile.twitter.com" rel="nofo...                  None
# 2  <a href="https://mobile.twitter.com" rel="nofo...                  None
# 3  <a href="http://twitter.com/download/iphone" r...                  None
# 4  <a href="https://sproutsocial.com" rel="nofoll...                  None
#
#   in_reply_to_status_id_str  ...  \
# 0                      None  ...
# 1                      None  ...
# 2                      None  ...
# 3                      None  ...
# 4                      None  ...
#
#                              quoted_status_permalink  \
# 0  {'url': 'https://t.co/PKlrVZvQuK', 'expanded':...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        quoted_status retweet_count  \
# 0  {'created_at': 'Sun Sep 25 03:20:07 +0000 2022...             0
# 1                                                NaN             2
# 2                                                NaN             1
# 3                                                NaN             1
# 4                                                NaN             0
#
#   favorite_count favorited retweeted possibly_sensitive lang  \
# 0              4     False     False              False  qme
# 1              6     False     False              False   en
# 2              5     False     False              False   en
# 3              0     False     False                NaN   en
# 4              1     False     False              False   en
#
#                                    extended_entities  \
# 0                                                NaN
# 1  {'media': [{'id': 1573358140590112769, 'id_str...
# 2  {'media': [{'id': 1572964261302870016, 'id_str...
# 3                                                NaN
# 4  {'media': [{'id': 1572336048432189440, 'id_str...
#
#                                     retweeted_status
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {'created_at': 'Wed Sep 21 00:17:41 +0000 2022...
# 4                                                NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Action 3: get data from a celebrity's Twitter page to Pandas Dataframe (at least 20 tweets)
#
# 1. get at least 20 variables (columns).
